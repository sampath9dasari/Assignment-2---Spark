# %% [markdown]
# # Big Data Programming - Assignment 2

# %% [markdown]
# ## Using Stack Exchange - Datascience dump

# %% [markdown]
# In this assignment, We are going to use RDDs from pyspark to answer some questions regarding the data. We will use Lambda functions to perform required operations for most part.

# %% [markdown]
# ### Importing required classes

# %% [markdown]
# We will import the following classes :
#
# * 'SparkSession' to initialize the Spark Context,
# * 'xml.etree.ElementTree' for parsing the xml files from StackExchange Data Science dump,
# * 're' is the python standard library for regular expressions,
# * 'pprint' module is to format the printing of data
#
# We will initialize sparkContext from SparkSession.builder

# %%
from pyspark.sql import SparkSession
import xml.etree.ElementTree as ET
import re
from pprint import pprint

spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %% [markdown]
# ### Reading in the Users.xml data into a RDD
# We will parse the XML data using python standard library xml.etree. We will parse the XML into a list of dictionaries and then parallelize this list into a RDD.
#
# So this list will have a python dictionary in every row.

# %%
UsersXmlData = ET.parse('../data_files/datascience/Users.xml')
Users = sc.parallelize([item.attrib for item in UsersXmlData.getroot()])
print("No of records in Users.xml : ",Users.count())
print("Sample Record :")
pprint(Users.first(),width=100)
# Out:
# No of records in Users.xml :  66951
# Sample Record :
# {'AboutMe': "<p>Hi, I'm not really a person.</p>\n"
#             '\n'
#             "<p>I'm a background process that helps keep this site clean!</p>\n"
#             '\n'
#             '<p>I do things like</p>\n'
#             '\n'
#             '<ul>\n'
#             '<li>Randomly poke old unanswered questions every hour so they get some '
#             'attention</li>\n'
#             '<li>Own community questions and answers so nobody gets unnecessary reputation from '
#             'them</li>\n'
#             '<li>Own downvotes on spam/evil posts that get permanently deleted</li>\n'
#             '<li>Own suggested edits from anonymous users</li>\n'
#             '<li><a href="http://meta.stackexchange.com/a/92006">Remove abandoned '
#             'questions</a></li>\n'
#             '</ul>\n',
#  'AccountId': '-1',
#  'CreationDate': '2014-05-13T21:29:22.820',
#  'DisplayName': 'Community',
#  'DownVotes': '1325',
#  'Id': '-1',
#  'LastAccessDate': '2014-05-13T21:29:22.820',
#  'Location': 'on the server farm',
#  'Reputation': '1',
#  'UpVotes': '798',
#  'Views': '0',
#  'WebsiteUrl': 'http://meta.stackexchange.com/'}

# %% [markdown]
# ### 1) From the Users.xml file, find all users which are from Georgia and output to screen their DisplayName only. (20 points)
#
# We are using the functionailty of a Python dictionary, which is loaded into each row of the RDD. We will use 'filter' function to filter for lines with values 'GEORGIA' and 'GA'.
#
# We use function 'get' to find the value for a specific key, while handling the situation where we might not have that key in a specific row.

# %%
GeorgiaUsers = Users.filter(lambda line : 
                            ('GEORGIA' in line.get('Location',"").upper() or 
                             'GA' in line.get('Location',"")))
GeorgiaUsers.persist()
print('No. of users from Georgia :', GeorgiaUsers.count())
print()
GeorgiaUserNames = GeorgiaUsers.map(lambda line : line['DisplayName'])
GeorgiaUsers.unpersist()
print('The Display names of Users from Georgia : ')
print()
pprint(GeorgiaUserNames.collect())
# Out:
# No. of users from Georgia : 167
#
# The Display names of Users from Georgia :
#
# ['Tony Boyles',
#  'pkerl',
#  'Nick Larsen',
#  'gfritz',
#  'Aleksandr Blekh',
#  'Michael',
#  'Ayush',
#  'azoorob',
#  'ontek',
#  'Aravind R. Yarram',
#  'ilya',
#  'vkb',
#  'Daisuke Aramaki',
#  'tempusfugit',
#  'Henry Crutcher',
#  'Goddard',
#  'Matt Simpson',
#  'Peter Woolfitt',
#  'Giorgi Gzirishvili',
#  'matt biskup',
#  'Jason W',
#  'Peter Mourfield',
#  'Magsol',
#  'Bob Baxley',
#  'Alex Azazel',
#  'badjr',
#  'mplunney',
#  'YC Hu',
#  'ryan',
#  'Patrick Gerbes',
#  'Ilya Lapitan',
#  'Dan Anton',
#  'pradyumnad',
#  'Manish Ranjan',
#  'Dato Janez',
#  'Psidom',
#  'Teresa Madsen',
#  'Neuromeda',
#  'Brandon',
#  'jpm',
#  'Mr. Rooter of Savannah',
#  'Mr. Rooter of Southeast GA',
#  'Abesalomi Gogatishvili',
#  'Khiem Ha',
#  'Jenna Kwon',
#  'Tedo G.',
#  'mlibre',
#  'Ahmet Cecen',
#  'Jeff',
#  'Guy Gordon',
#  'C3Theo',
#  'niru dyogi',
#  'Vinitha Palani',
#  'Mac18',
#  'Andrew',
#  'Aditya Gogoi',
#  'turtlemonvh',
#  'Lewis Rodgers',
#  'Tarun Luthra',
#  'Jesse Scherer',
#  'Devendra Lattu',
#  'cosmosa',
#  'Todd Dawson',
#  'ironv',
#  'Mboolean',
#  'Jimd',
#  'Melinda Weathers',
#  'N.C.W.',
#  'David F',
#  'PSInf',
#  'Chirag',
#  'Sandeep Gunda',
#  'hellofanengineer',
#  'Will Gao',
#  'Oriol Mirosa',
#  'Andrew King',
#  'David',
#  'rajb245',
#  'Sealander',
#  'afshin',
#  'Ashish Powani',
#  'Boris N.',
#  'Atul Kaushik',
#  'Harnoor Singh',
#  'Vincent',
#  'Tiago Cogumbreiro',
#  'cbarrick',
#  'Len Greski',
#  'red_eight',
#  'PEBKAC',
#  'Christoph',
#  'G.T.',
#  'Bryce',
#  'David Hofmann',
#  'nburn42',
#  'donlan',
#  'Nick M',
#  'Kiran',
#  'BarclayK',
#  'Dato Gogolashvili',
#  'Zer0k',
#  'dportman',
#  'Shishir Suman',
#  'Scott',
#  'JessicaRabi',
#  'Baxter',
#  'Rama Ananda',
#  'Dr. Strange',
#  'Shahan M',
#  'wgreenihrcorp',
#  'zongyan',
#  'David Jashi',
#  'Alexandre',
#  'rams',
#  'Ilia Chigogidze',
#  'John Barbour',
#  'The_Flin',
#  'DaulPavid',
#  'Amandeep Jiddewar',
#  'Erica Rosa',
#  'user1410665',
#  'empoleon',
#  'Willie-G',
#  'Deepak Shenoy',
#  'Ragnar Lothbrok',
#  'Deontaé Le Pew',
#  'Doctorambient',
#  'Vidya',
#  'Vatsal Srivastava',
#  'Dean Webb',
#  'Tae-Sung Shin',
#  'Sam Washburn',
#  'Loisaida Sam Sandberg',
#  'wayne green',
#  'gnorman',
#  'Clark Lin',
#  'Floydian',
#  'Meng Zhao',
#  'Manikanta Reddy D',
#  'devarsh raghnathbhai patel',
#  'Myron Slaw',
#  'rmooney',
#  'Gio Nari',
#  'mike_stevs',
#  'Gary Lai',
#  'ajroot',
#  'Daniel',
#  'phos',
#  'Lance Ruo Zhang',
#  'Spencer-Price',
#  'Stephen Ewing',
#  'alerera',
#  'addi wei',
#  'Alex V',
#  'Rob',
#  'Rajan',
#  'Ram',
#  'jGaboardi',
#  'Max Boonbandansook',
#  'zachdj',
#  'David Zhou',
#  'ps0604',
#  'treysp',
#  'Eduardo Trunci',
#  'Squ1rr3lz',
#  'Tiji Mathew',
#  'user3776637']

# %% [markdown]
# ### 2) Using the Users.xml file, provide the count for all users which joined (CreationDate) in 2017. (30 points). Output this to the screen.
#
# Using the CreationDate as key, we can find the value 2017 and filter for those lines.

# %%
Users2017 = Users.filter(lambda line : '2017' in line['CreationDate'])
print('Users who joined in 2017 : ', Users2017.count())
# Out:
# Users who joined in 2017 :  14239

# %% [markdown]
# ### Reading in PostHistory.xml into a RDD

# %%
PostXmlData = ET.parse('../data_files/datascience/PostHistory.xml')
PostHistory = sc.parallelize([item.attrib for item in PostXmlData.getroot()])
print('No of Records in PostHistory.xml : ',PostHistory.count())
print("Sample Record :")
print()
pprint(PostHistory.first(),width=100)
# Out:
# No of Records in PostHistory.xml :  121522
# Sample Record :
#
# {'CreationDate': '2014-05-13T23:58:30.457',
#  'Id': '7',
#  'PostHistoryTypeId': '2',
#  'PostId': '5',
#  'RevisionGUID': '009bca93-fce2-44ed-a277-a8452650a627',
#  'Text': "I've always been interested in machine learning, but I can't figure out one thing about "
#          'starting out with a simple "Hello World" example - how can I avoid hard-coding '
#          'behavior?\r\n'
#          '\r\n'
#          'For example, if I wanted to "teach" a bot how to avoid randomly placed obstacles, I '
#          "couldn't just use relative motion, because the obstacles move around, but I don't want "
#          'to hard code, say, distance, because that ruins the whole point of machine learning.\r\n'
#          '\r\n'
#          'Obviously, randomly generating code would be impractical, so how could I do this?',
#  'UserId': '5'}

# %% [markdown]
# ### 3) Using the PostHistory file, count the number of Posts that feature the words “Spark” and “Scala”. Output this to the screen. (20 points)
#
# In the 'Text' column which contains the actual post, we are filtering for posts with either the word SPARK and SCALA and printing the count of them.

# %%
PostSearch = PostHistory.filter(lambda line : 
                                ('SPARK' in line.get('Text',"").upper() and 
                                 'SCALA' in line.get('Text',"").upper()))
print("No of Posts containing the words 'SCALA' or 'SPARK' : ", PostSearch.count())
# Out:
# No of Posts containing the words 'SCALA' or 'SPARK' :  211

# %% [markdown]
# ### 4) Using the PostHistory file, provide a total count of the words used by each distinct user. In other words, count all words in all posts for each user and display this to screen. You can only identify users by the UserID (30 points). You get 15 bonus points if you get the actual DisplayName of the user.
#
# We will use the regular expressions for this question.
# * The RegEx - '\w+' evaluates to matching all alphanumeric characters along with '_'.
# * The 'findall' function works on iterating through the string to separate all the matches to provide us a list of separated strings.
# * We use Map function to make a RDD consisting UserID, Count of words from Post and '1'(a arbitrary value to be used to get the count of posts for future use).
# * We use 'reduceByKey' to summarize the number of words in the posts and the arbitrary '1' value for total post count and show the total of those values by key, which is 'UserId' here.
# * We make another RDD just containing UserId and DisplayName using the map function.
# * Now we join the RDD with PostCount and DisplayName using UserID as key to get all the data into a single RDD.
#
# * Finally we will use map one more time to print the data in user friendly format

# %%
PostCount = PostHistory.map(lambda line : 
                            (line.get('UserId',"No User ID"),
                             (len(re.findall(r'\w+', line.get('Text',""))),1)))

PostsByUser = PostCount.reduceByKey(lambda x,y : (x[0]+y[0],x[1]+y[1]))
print('User ID count from Summary : ', PostsByUser.count())

UserDisplayName = Users.map(lambda line : (line['Id'],line.get('DisplayName','No Display Name')))
PostsByName = UserDisplayName.join(PostsByUser)

PostsByNameOut = PostsByName.map(lambda line : line[1][0]+'('+line[0]+') - '+str(line[1][1][0]))
print('DISPLAYNAME(USERID) - Count of Words')
print()
pprint(PostsByNameOut.collect(),width=50)
# Out:
# User ID count from Summary :  14101
# DISPLAYNAME(USERID) - Count of Words
#
# ['buruzaemon(24) - 1406',
#  'Alex I(26) - 12280',
#  'Robert Cartaino(50) - 22',
#  'Clayton(53) - 801',
#  'Dan C(64) - 107',
#  'Apollo(70) - 323',
#  'Srikar Appalaraju(77) - 2087',
#  'Damian Melniczuk(82) - 1920',
#  'Igor Bobriakov(88) - 400',
#  'Bryan(102) - 287',
#  'rapaio(108) - 25344',
#  'vefthym(113) - 954',
#  'Johnny000(115) - 2462',
#  'Marc Claesen(119) - 462',
#  'Stu(141) - 557',
#  'Memming(154) - 68',
#  'Jay Godse(157) - 62',
#  'blunders(158) - 3836',
#  'Gregor(160) - 122',
#  'user179(179) - 41',
#  'Oleksi(180) - 55',
#  'Cici(192) - 149',
#  'sushant-hiray(226) - 211',
#  'blue-sky(237) - 914',
#  'Chris Simokat(249) - 141',
#  'phyrox(278) - 123',
#  'Alireza(283) - 245',
#  'miraculixx(389) - 2651',
#  'alaiacano(414) - 209',
#  'idclark(426) - 603',
#  'hroptatyr(451) - 441',
#  'erogol(464) - 277',
#  'Stanpol(478) - 374',
#  'user490(490) - 38',
#  'Brown_Dynamite(496) - 313',
#  'azza-bazoo(508) - 58',
#  'tilo.wiklund(536) - 92',
#  'indico(548) - 7551',
#  'Yannis Assael(552) - 128',
#  'lsdr(553) - 436',
#  'Tim(562) - 379',
#  'tokestermw(588) - 407',
#  't_m(645) - 107',
#  'vonjd(690) - 150',
#  'Bastiaan Quast(700) - 350',
#  'user721(721) - 65',
#  'Gerenuk(723) - 1837',
#  'Kaushalya(733) - 969',
#  'Patlaf(737) - 135',
#  'Christian Sauer(791) - 1248',
#  'Rodrigo Rivera(797) - 138',
#  'Kim(801) - 88',
#  'Alexey Grigorev(816) - 7524',
#  'Charlie Greenbacker(819) - 3479',
#  'user3279453(839) - 154',
#  'fxm(883) - 101',
#  'Armin(901) - 225',
#  'user3663635(957) - 98',
#  'Abdelmawla(960) - 203',
#  'martina(982) - 1088',
#  'mlespiau(1057) - 381',
#  'Frost(1147) - 298',
#  'GeorgeOfTheRF(1151) - 1723',
#  'user2592989(1162) - 313',
#  'Phonon(1163) - 589',
#  'Islam El Hosary(1220) - 90',
#  'user3659451(1223) - 919',
#  'user3782364(1235) - 600',
#  'pincopallino(1244) - 1515',
#  'user48914(1257) - 254',
#  'Trylks(1281) - 441',
#  'soandos(1334) - 89',
#  'Stephane Rolland(1352) - 745',
#  'logc(1367) - 8115',
#  'noleto(1368) - 87',
#  'Alx49(1384) - 101',
#  'asdf(1409) - 293',
#  'mjul(1424) - 2538',
#  'Aleksandr Blekh(2452) - 31446',
#  'johnhidley(2458) - 600',
#  'Keith(2511) - 2536',
#  'Dynamic Stardust(2515) - 5430',
#  'chewpakabra(2573) - 3618',
#  'Karsten 7.(2580) - 420',
#  'karthikbharadwaj(2608) - 101',
#  'aidankmcl(2653) - 94',
#  'samthebest(2668) - 878',
#  'Tom(2711) - 276',
#  'Hack-R(2723) - 12841',
#  'Dipanjan Sarkar(2744) - 93',
#  'rohitjv(2756) - 52',
#  'user4959(2840) - 74',
#  'sparc_spread(2862) - 140',
#  'mommi84(2912) - 20',
#  'dani(2913) - 179',
#  'universalkernel(2928) - 378',
#  'Noor(2948) - 40',
#  'Maxim Galushka(2958) - 430',
#  'rcs(2961) - 3666',
#  'deong(2975) - 1047',
#  'Michael Hooreman(3024) - 5754',
#  'user1913171(3030) - 130',
#  'Upul Bandara(3040) - 118',
#  'pir(3044) - 2323',
#  'Seraphina(3058) - 82',
#  'Jane Wayne(3083) - 835',
#  'Jordan Bentley(3085) - 58',
#  'KayV(3089) - 87',
#  'theclaymethod(3100) - 24',
#  'Ted Dunning(3153) - 85',
#  'papacostas(3203) - 101',
#  'Rahul Agarwal(3211) - 241',
#  'user76170(3223) - 205',
#  'kinkajou(3230) - 558',
#  'DACW(3232) - 183',
#  'Harjeet Kumar(3259) - 32',
#  'Guforu(3281) - 3734',
#  'Paul K(3283) - 368',
#  'Hendrik(3284) - 150',
#  'user62198(3314) - 8231',
#  'Eleanore(3321) - 214',
#  'user115415(3346) - 72',
#  'AndriusZ(3377) - 284',
#  'Gyan Veda(3412) - 50',
#  'Glen Swan(3417) - 2109',
#  'innovIsmail(3433) - 166',
#  'user1269942(3457) - 774',
#  'sheldonkreger(3466) - 5048',
#  'Sitz Blogz(3486) - 1130',
#  'user92953(3507) - 67',
#  'David Pepper(3510) - 511',
#  'machine-wisdom(3540) - 149',
#  'KurioZ7(3550) - 252',
#  'user3131969(3551) - 45',
#  'DaveA(3568) - 310',
#  'p.j(3570) - 300',
#  'Rakhi Ssdd(3598) - 41',
#  'Tyler(3605) - 161',
#  'Andrew - OpenGeoCode(3609) - 723',
#  'PlagTag(4676) - 376',
#  'prudenko(4679) - 346',
#  'Amstell(4697) - 298',
#  'i5Vemula(4711) - 130',
#  'tashuhka(4719) - 401',
#  'angleto(4784) - 60',
#  'TuanDT(4803) - 115',
#  'goh(4841) - 97',
#  'iboboboru(4847) - 14',
#  'James Ravenscroft(4853) - 318',
#  'aa51(4859) - 136',
#  'kylerthecreator(4897) - 1335',
#  'Jerome(4929) - 29',
#  'vondip(4953) - 157',
#  'nahraf(4993) - 150',
#  'Nick Lashinsky(5004) - 228',
#  'k6adams(5023) - 154',
#  'Swan87(5029) - 551',
#  'user1192748(5038) - 314',
#  'Colin Winhall(5066) - 181',
#  'cyclic(5079) - 151',
#  'Oleg Roderick(5083) - 120',
#  'Hobbes(5113) - 320',
#  'Javierfdr(5143) - 9220',
#  'goangit(5153) - 765',
#  'JC R(5165) - 354',
#  'Pramit(5179) - 1329',
#  'shihpeng(5184) - 585',
#  'user991710(5199) - 1132',
#  'ccanduc(5227) - 122',
#  'danielchalef(5233) - 112',
#  'cbeleites(5268) - 5099',
#  'Stumbler(5290) - 1045',
#  'Lauren(5298) - 107',
#  'conjectures(5303) - 1809',
#  'Solarbear(5306) - 29',
#  'ponythewhite(5314) - 210',
#  'Luke(5344) - 123',
#  'rbaleksandar(5356) - 594',
#  'David Batista(6518) - 887',
#  'zipp(6527) - 406',
#  'Rajeev Singh(6534) - 168',
#  'zen(6536) - 35',
#  'Valentas(6550) - 5394',
#  'odkken(6568) - 355',
#  'lotyrin(6585) - 151',
#  'Anchika Agarwal(6598) - 540',
#  'JackSie(6602) - 119',
#  'flow(6606) - 548',
#  'oDDsKooL(6619) - 72',
#  'Eilia(6641) - 56',
#  'habedi(6656) - 53',
#  'cakesofwrath(6660) - 56',
#  'Deepraj Kunnath(6682) - 268',
#  'Dennis(7713) - 198',
#  'Mohammed Ashiq(7725) - 125',
#  'aamir23(7736) - 125',
#  'Nagia(7739) - 413',
#  'Vladislavs Dovgalecs(7848) - 2658',
#  'Steve Rowland(7909) - 134',
#  'DaveRGP(7916) - 571',
#  'Maksim Khaitovich(7969) - 3627',
#  'Seth Stephens-Davidowitz(7972) - 7',
#  'image_doctor(7980) - 4156',
#  'Dimitris(7982) - 57',
#  'Uri Merhav(7999) - 512',
#  'Anurag Gupta(8003) - 44',
#  'Leon palafox(8065) - 663',
#  'Chong Zheng(8073) - 76',
#  'Nart Barileva(8074) - 178',
#  'JBD(8105) - 252',
#  'Omri374(8113) - 933',
#  'Nicole(8123) - 57',
#  'Ognjen(8158) - 1923',
#  'Philip Graham(8200) - 78',
#  'Yohan Chung(8208) - 131',
#  'tjltjl(8210) - 44',
#  'Chiffa(8214) - 1144',
#  'femibyte(8234) - 119',
#  'Qbik(8237) - 362',
#  'user137927(8240) - 452',
#  'shadow_dev(8251) - 564',
#  'Gopinath Subbegowda(8257) - 54',
#  'zbinsd(8262) - 18',
#  'likelihoodFunction(8273) - 151',
#  'gojomo(8278) - 195',
#  'eflores89(8296) - 97',
#  'MattAttack(8314) - 125',
#  'Matt(8319) - 135',
#  'Fritz(8335) - 428',
#  'Luca(8337) - 658',
#  'Hamza(8357) - 57',
#  'Samizdat(8368) - 92',
#  'Ferenc Huszár(8376) - 285',
#  'apSTRK(8381) - 199',
#  'harshil(8391) - 47',
#  'mcg256(8392) - 205',
#  "Stas Prihod'co(8394) - 380",
#  'M.Dax(8395) - 794',
#  'Leon(8410) - 226',
#  'Jeffrey Evans(8463) - 99',
#  'user67275(8478) - 469',
#  'Bipin(8516) - 116',
#  'Piyush Panigrahi(8526) - 208',
#  'Abhinav(8528) - 71',
#  'vtechie(8540) - 213',
#  'vagabond(8553) - 307',
#  'edgaralienfoe(8626) - 127',
#  'Vit D(8645) - 81',
#  'Rob Hyndman(8646) - 148',
#  'Abhishek Tripathi(8681) - 148',
#  'Tobi(8686) - 355',
#  'Brett(8692) - 611',
#  'dac2002(8704) - 156',
#  'Johannes Bauer(8714) - 305',
#  'Jaishree Rout(8729) - 1836',
#  'Brian Borchers(8754) - 212',
#  'hlin117(8774) - 686',
#  'Marcus Torrez(8796) - 54',
#  'jackStinger(8830) - 193',
#  'Rejeena(8839) - 124',
#  'sfactor(8841) - 162',
#  'Rob(8875) - 61',
#  'animuson(8877) - 0',
#  'lbenitesanchez(8904) - 45',
#  'Ved(8923) - 41',
#  'Amit Kumar Gupta(8948) - 196',
#  'john mangual(8956) - 96',
#  'Martin(8960) - 66',
#  'Pinocchio(8995) - 242',
#  'Ciochi(9033) - 309',
#  'jul(9050) - 68',
#  'lanenok(9085) - 4174',
#  'user1830108(9097) - 81',
#  'user3780968(9114) - 1080',
#  'Jose(9127) - 133',
#  'Alejandro Simkievich(9197) - 2209',
#  'Victor Bellon(9223) - 54',
#  'Quantopik(9225) - 481',
#  'Ann Feeney(9236) - 260',
#  'Henry Qiu(9246) - 484',
#  'firelynx(9270) - 198',
#  'bmurauer(9281) - 200',
#  'user2474895(9371) - 36',
#  'spikedlatte(9383) - 15',
#  'Eric Baldwin(9394) - 241',
#  'Will(9433) - 427',
#  'Totem(9461) - 1920',
#  'Jordan A(9483) - 1765',
#  'Antonio Edgar Martinez(9488) - 239',
#  'SeanOCVN(9492) - 170',
#  'Jimmys(9501) - 33',
#  'Jakub Kotowski(9508) - 831',
#  'grill(9511) - 426',
#  'Srinivas K(9577) - 522',
#  'mohamedzajith(9586) - 96',
#  'James Allen(9587) - 1709',
#  'Marcel Chastain(9591) - 232',
#  'Jerome Smith(9595) - 68',
#  'Akuryo(9608) - 232',
#  'itdxer(9634) - 773',
#  'Murali(9663) - 1107',
#  'ShainaR(9700) - 610',
#  'Felipe(9771) - 40',
#  'user242782(9787) - 375',
#  'kosnkov(9799) - 343',
#  'device_exec(9801) - 1283',
#  'Chris(9807) - 231',
#  'David(9838) - 369',
#  'DeanLa(9910) - 309',
#  'cladelpino(9928) - 209',
#  'Rhonda(9947) - 364',
#  'Berit Larsen(9960) - 212',
#  'untitledprogrammer(9966) - 2313',
#  'Rodrigo Nader(9988) - 1339',
#  'Michael Protz(9995) - 659',
#  'JGreenwell(10019) - 120',
#  'EngineeredBrain(10049) - 675',
#  'Olel Daniel(10076) - 190',
#  'Alexandru Daia(10094) - 548',
#  'Indy(10123) - 88',
#  'Monty(10141) - 144',
#  'sarker306(10163) - 81',
#  'jknappen(10169) - 1867',
#  'Dan Miles(10170) - 217',
#  'spt025(10210) - 702',
#  'Digital Dude(10225) - 107',
#  'user3841581(10240) - 216',
#  'Nifras Ismail(10245) - 88',
#  'grasshopper(10255) - 233',
#  'Majid Einian(10270) - 678',
#  'Stéphanie C(10275) - 1912',
#  'Magsol(10277) - 20',
#  'akashrajkn(10291) - 40',
#  'Ardeshir(10318) - 229',
#  'user10322(10322) - 80',
#  'Ire(10344) - 74',
#  'PhilMacKay(10346) - 541',
#  'Srini Vemula(10352) - 225',
#  'Yash Lundia(10353) - 61',
#  'bhavinpatel(10391) - 177',
#  'Martin Vseticka(10404) - 110',
#  'Matt Sornson(10415) - 23',
#  'joy(10416) - 730',
#  'Jareth Holt(10427) - 984',
#  'kev(10436) - 38',
#  'Übel Yildmar(10437) - 43',
#  'user10456(10456) - 76',
#  'Vinay Joshi(10479) - 497',
#  'Jabberwockey(10506) - 560',
#  'Chris(10513) - 616',
#  'kdbanman(10531) - 303',
#  'blah(10559) - 266',
#  'Ron Brogan(10596) - 210',
#  '2daaa(10654) - 76',
#  'MD004(10683) - 2256',
#  'nmerci(10694) - 486',
#  'Jacrys(10709) - 259',
#  'Kristian(10761) - 774',
#  'Rebecca Morgan(10786) - 37',
#  'Chesnokov Yuriy(10790) - 128',
#  'Beta(10810) - 2603',
#  'skan(10815) - 726',
#  'Nik(10844) - 74',
#  'Jacob H(10845) - 159',
#  'gcd(10846) - 235',
#  'Amir(10870) - 719',
#  'arcee123(10881) - 187',
#  'Rjz Satvara(10891) - 52',
#  'deeep(10899) - 159',
#  'Ghostintheshell(10915) - 275',
#  'Jamison(10964) - 90',
#  'Michael(10972) - 308',
#  'psql(10983) - 956',
#  'Victor Yip(10990) - 207',
#  'Net_Raider(11034) - 72',
#  'rkjt50r983(11062) - 187',
#  'Martin Modrák(11077) - 40',
#  'Dirk Nachbar(11080) - 248',
#  'Cassandra(11094) - 228',
#  'Dawny33(11097) - 70277',
#  'user3720596(11116) - 64',
#  'João Almeida(11121) - 641',
#  'Sarath(12183) - 198',
#  'Piriko(12193) - 98',
#  'Gary(12202) - 4816',
#  'Simon(12206) - 3771',
#  'Hari(12207) - 22',
#  'NightFurry(12217) - 157',
#  'epx(12219) - 106',
#  'Tim Roberson(12265) - 117',
#  'tguzella(12290) - 314',
#  'jason.p.pickering(12316) - 20',
#  'Arkan(12345) - 3683',
#  'Rohit(12350) - 190',
#  'Sony(12362) - 111',
#  'user2409011(12377) - 794',
#  'gaurus(12378) - 213',
#  'user12395(12395) - 90',
#  'happycube(12408) - 36',
#  'jaig(12411) - 244',
#  'sebastianspiegel(12443) - 1831',
#  'Jane Foster(12457) - 68',
#  'jamesmf(12473) - 10961',
#  'Anna(12496) - 117',
#  'Justin(12497) - 298',
#  'tofu_bacon(12516) - 224',
#  'keval(12533) - 432',
#  'Arun(12554) - 264',
#  'hexagon(12556) - 210',
#  'sunny(12586) - 1756',
#  'MASL(12603) - 2038',
#  'Tristan Reid(12626) - 254',
#  'zero323(12632) - 149',
#  'DaveTheScientist(12710) - 238',
#  'dom(12712) - 26',
#  'ultron(12771) - 782',
#  'shark8me(12786) - 262',
#  'Tobias Würfl(12798) - 1391',
#  'arschie(12827) - 97',
#  'sebap123(12855) - 79',
#  'Samuel Smith(12861) - 550',
#  'Matthew Graves(12876) - 6572',
#  'ashish chopra(12911) - 173',
#  'Seppo Enarvi(12932) - 1047',
#  'user12949(12949) - 62',
#  'Asif Neyaz Azeez(12952) - 56',
#  'Wilson Freitas(12960) - 969',
#  'Hooked(12963) - 235',
#  'joc(12972) - 93',
#  'Sredny M Casanova(12996) - 66',
#  'CHP(13002) - 1288',
#  'coffeinjunky(13021) - 262',
#  'maggs(13046) - 1656',
#  'MD Luffy(13056) - 440',
#  'Doug Fir(13106) - 279',
#  'James Bond(13120) - 363',
#  'ramana_k(13145) - 454',
#  'John(13154) - 52',
#  'Wendell Blatt(13168) - 700',
#  'Daniel(13175) - 166',
#  'daniel3412(13176) - 913',
#  'user6309(13182) - 60',
#  'Chris Snow(13237) - 231',
#  'user13254(13254) - 107',
#  'user2350366(13259) - 1940',
#  'Haroon Rashid(13291) - 4022',
#  'Maikel Leyva(13315) - 19',
#  'c.uent(13323) - 199',
#  'Kai(13348) - 453',
#  'Brian Ecker(13354) - 156',
#  'user2280549(13384) - 171',
#  'user13390(13390) - 158',
#  'ajrwhite(13416) - 634',
#  'Luis Alves(13447) - 225',
#  'user140323(13450) - 5157',
#  'Anuj Gupta(13457) - 595',
#  'saraw(13469) - 201',
#  'FaCoffee(13481) - 1484',
#  'Steve(13496) - 39',
#  'Harsh(13505) - 6895',
#  'user13512(13512) - 116',
#  'AlFagera(13516) - 63',
#  'SHASHANK GUPTA(13518) - 4300',
#  'Jeffrey04(13562) - 1652',
#  'ARB(13593) - 333',
#  'André Risnes(13596) - 398',
#  'user2088176(13639) - 131',
#  'MarvMind(13662) - 1447',
#  'user(13736) - 10762',
#  'Mephy(13748) - 7891',
#  'jainp(13770) - 286',
#  'xyz(13772) - 71',
#  'StevenA(13775) - 1245',
#  'daniel451(13809) - 1180',
#  'Jacky Ma(13818) - 259',
#  'aamir23(13855) - 177',
#  'Rami(13891) - 9537',
#  'Dong (13905) - 51',
#  'AnserGIS(13955) - 142',
#  'RHC(13977) - 130',
#  'guaraqe(13978) - 442',
#  'fluency03(14007) - 105',
#  'scf(14044) - 249',
#  'mattdns(14047) - 395',
#  'ryan(14050) - 151',
#  'Lenar Hoyt(14053) - 467',
#  'cyberj0g(14059) - 69',
#  'Arnold Klein(14070) - 1613',
#  'hlaubisch(14073) - 229',
#  'potatosoup(14137) - 88',
#  'okebz(14154) - 242',
#  'jmvllt(14200) - 1102',
#  'Carlos del Gatos(14229) - 39',
#  'Ildar Gabdrakhmanov(14267) - 561',
#  'Addem(14327) - 173',
#  'Vini(14332) - 494',
#  'Artem Betley(14339) - 240',
#  'Bg1850(14353) - 100',
#  'Jason Donnald(14383) - 119',
#  'Jason Donnald(14384) - 383',
#  'Vinay(14391) - 146',
#  'Rajan Kumar Kharel(14416) - 157',
#  'user90772(14487) - 742',
#  'mrry(14517) - 73',
#  'KT.(14519) - 17830',
#  'Madness(14531) - 104',
#  'Anonan(14533) - 124',
#  'SemanticBeeng(14542) - 547',
#  'jonepatr(14556) - 263',
#  'Asmus(14558) - 55',
#  'Philip C. (14560) - 2290',
#  'darksurfer(14562) - 261',
#  'Statwonk(14572) - 101',
#  'David Dao(14578) - 224',
#  'Karlo(14591) - 157',
#  'Maciej K.(14633) - 50',
#  'BlackHawk(14641) - 204',
#  'zezi(14642) - 140',
#  'kmshannon(14654) - 262',
#  'Anks(14656) - 189',
#  'orschiro(14660) - 42',
#  'ncasas(14675) - 26370',
#  'prashanth(14688) - 58',
#  'matthew henry(14735) - 238',
#  'Mpizos Dimitris(14736) - 1114',
#  'westonplatter(14812) - 46',
#  'Guillaume Vauvert(14831) - 472',
#  'Stefano(14852) - 107',
#  'killercode(14886) - 417',
#  'Doug Manuel(14894) - 119',
#  'hbaderts(14906) - 8219',
#  'Yann(14912) - 39',
#  'Severin Pappadeux(14987) - 19',
#  'ricksmt(14989) - 387',
#  'Deschutron(15002) - 95',
#  'Jessiah Burgess(15083) - 277',
#  'user2075215(15157) - 173',
#  'user15163(15163) - 202',
#  'user15171(15171) - 37',
#  'user15180(15180) - 124',
#  'Chao-Hua Yu(15211) - 119',
#  'Clash(15234) - 244',
#  'Crizly(15311) - 103',
#  'Michael(15408) - 134',
#  'farmi(15445) - 633',
#  'MLgeek (15469) - 74',
#  'Nathaniel Hendrix(15470) - 27',
#  'Robino(15547) - 241',
#  'parvij(15569) - 3462',
#  'neurite(15624) - 369',
#  'nikicc(15685) - 841',
#  'huji1991(15686) - 119',
#  'R. Doe(15690) - 1235',
#  'trizzou(15720) - 83',
#  'Andrei Pokrovsky(15766) - 1786',
#  'Charlie(15797) - 110',
#  'dmanuge(15807) - 415',
#  'Koushik(15861) - 71',
#  'Ashika Umanga Umagiliya(15897) - 404',
#  'The6thSense(15902) - 2469',
#  'user15921(15921) - 51',
#  'Taylor(15942) - 69',
#  'So S(15946) - 2483',
#  'user3939059(15961) - 840',
#  'Rabbit(16001) - 334',
#  'machlear7(16046) - 297',
#  'user16058(16058) - 60',
#  'Yuchi Matsuoka(16101) - 134',
#  'mandata(16145) - 25',
#  'Lydie(16152) - 228',
#  'ode2k(16166) - 249',
#  'Data_D(16179) - 220',
#  'Neal(16211) - 5',
#  'Jon(16220) - 2115',
#  'JoeM05(16238) - 167',
#  'Nishi(16255) - 65',
#  'InquisitiveCrow(16279) - 129',
#  'Randomize(16280) - 98',
#  'error_null_pointer(16291) - 175',
#  'John Hass(16310) - 352',
#  'Mary(16312) - 283',
#  'ds21(16337) - 46',
#  'tevlon84(16353) - 76',
#  'PidgeyUsedGust(16366) - 200',
#  'flow(16416) - 108',
#  'Jetzler(16465) - 309',
#  'ksopyla(16487) - 29',
#  'Mdev(16520) - 58',
#  'Magnus Robert Carl Wootton(16528) - 140',
#  'Ali Raza Memon(16546) - 312',
#  'neelshiv(16548) - 469',
#  'ImperativelyAblative(16558) - 993',
#  'Arnab Biswas(16581) - 661',
#  'Cara Wogsland(16590) - 304',
#  'Istvan(16625) - 177',
#  'jai (16646) - 121',
#  'fstanis(16651) - 255',
#  'user3396592(16661) - 100',
#  'chchannn(16677) - 126',
#  'Carlos C(16712) - 1388',
#  'Pablo(16723) - 178',
#  'Fhurrur(16735) - 1091',
#  'Nikita Chopra(16749) - 360',
#  'Rstall(16763) - 37',
#  'tim-dim(16772) - 136',
#  'user106751(16774) - 105',
#  'user16791(16791) - 240',
#  'haimen(16887) - 118',
#  'Dmitry Kandalov(16897) - 564',
#  'DataScientistWNB(16913) - 167',
#  'thanks_in_advance(16928) - 2352',
#  'Paritosh Tiwari(16943) - 145',
#  'user6046209(16966) - 154',
#  'adamwlev(16972) - 181',
#  'silverstone(17020) - 585',
#  'Ben Sandeen(17022) - 901',
#  'Shileen Upadhyay(17034) - 93',
#  'Quamber Ali(17041) - 81',
#  'user2543622(17054) - 1976',
#  'Data Science Dojo(17078) - 693',
#  'bma(17101) - 68',
#  'Simon(17149) - 85',
#  'RyanCacophony(17159) - 162',
#  'raK1(17169) - 28',
#  'Arul(17215) - 173',
#  'Jonathan Dine(17267) - 289',
#  'Rakan Nimer(17325) - 342',
#  'Issoufou(17331) - 142',
#  'YKS(17332) - 140',
#  'Eli Korvigo(17356) - 1473',
#  'user17381(17381) - 119',
#  'PyRe(17384) - 102',
#  'alwaysaskingquestions(17423) - 1850',
#  'Sam(17444) - 78',
#  'Mandar Chandorkar(17446) - 203',
#  'salvador(17451) - 196',
#  'Roberto Ferrer(17461) - 120',
#  'hans periag(17469) - 96',
#  'PeppermintBark(17520) - 349',
#  'JannaBotna(17536) - 131',
#  'E_net4(17538) - 3926',
#  'ashwinids(17558) - 62',
#  'John(17585) - 151',
#  'Sam(17594) - 431',
#  'John Newman(17596) - 833',
#  'fabian(17614) - 855',
#  'Timmmm(17618) - 1374',
#  'J_Heads(17640) - 422',
#  'Winter(17646) - 789',
#  'Ketakee Nimavat(17699) - 521',
#  'bl0b(17702) - 570',
#  'Ravindranath Akila(17757) - 7',
#  'gfursin(17768) - 431',
#  'bigdataumd(17771) - 1056',
#  'Jayant Mishra(17814) - 131',
#  'Bhavesh Oswal(17841) - 1000',
#  'PeyM87(17937) - 539',
#  'JudeLee(17987) - 634',
#  'ssan(18013) - 272',
#  'eli-k(18022) - 244',
#  'Slaventsiy(18028) - 297',
#  'machinery(18040) - 869',
#  'hellboy(18102) - 350',
#  'Anish(18115) - 54',
#  'muneeb(18140) - 56',
#  'mc07(18156) - 171',
#  'Aman Tandon(18170) - 334',
#  'user2076688(18195) - 101',
#  'paceholder(18219) - 320',
#  'Eric Conner(18235) - 118',
#  'Divi(18248) - 567',
#  'batu(18259) - 255',
#  'Dider(18271) - 231',
#  'Shakti(18313) - 564',
#  'Daia Alexandru(18321) - 205',
#  'MacGyver(18349) - 70',
#  'Anonymint(18369) - 1275',
#  'Bihaqo(18414) - 56',
#  'Vadim Smolyakov(18418) - 1591',
#  'Guido(18460) - 431',
#  'Munesh(18477) - 94',
#  'wordsforthewise(18481) - 217',
#  'Peter Krejzl(18501) - 461',
#  'felicienb(18509) - 95',
#  'Leland McInnes(18513) - 3105',
#  'khu(18624) - 19',
#  'shinvu(18632) - 562',
#  'FreedomToWin(18661) - 239',
#  'Benjamin Maurer(18680) - 476',
#  'Bob(18682) - 353',
#  'lllllllllllll(18693) - 363',
#  'Ole Petersen(18787) - 3794',
#  'Feras Odeh(18888) - 37',
#  'Kyle(18903) - 44',
#  'GameOfThrows(18969) - 129',
#  'ash(18984) - 219',
#  'nor0x(19003) - 125',
#  'user20160(19014) - 1042',
#  'miguelote(19058) - 57',
#  'Hasse Iona(19067) - 2042',
#  'user963263(19083) - 45',
#  'Mark Green(19100) - 186',
#  'lupi5(19113) - 568',
#  'nir(19147) - 1283',
#  'turtlepick(19167) - 83',
#  'dev93(19191) - 288',
#  'lucidyan(19220) - 96',
#  'Dariush(19258) - 49',
#  'Dan Piponi(19265) - 210',
#  'wolfe(19275) - 473',
#  'Luv Agarwal(19278) - 437',
#  'M Green(20297) - 26',
#  'Kajal Puri(20308) - 325',
#  'Mehdi(20311) - 353',
#  'lopsi(20321) - 177',
#  'Linda(20340) - 135',
#  'pepe(20374) - 1325',
#  'jochem_schelde(20389) - 231',
#  'Alexei Martianov(20448) - 528',
#  'divyum(20472) - 155',
#  'Lobna Alnabbash(20477) - 120',
#  'doktakay(20485) - 95',
#  'Tobias Kienzler(20495) - 59',
#  'Coeus2016(20513) - 335',
#  'user1901718(20525) - 123',
#  'tkazmer(20565) - 378',
#  'plexoos(20576) - 120',
#  'learning(20589) - 162',
#  'amir ladhar(20590) - 198',
#  'sagivmal(20594) - 200',
#  'Armon Safai(20635) - 425',
#  'Bryan - k0emt(20667) - 29',
#  'trebi(20687) - 330',
#  'user20703(20703) - 25',
#  'cumin(20704) - 68',
#  'Odingod(20714) - 119',
#  'durrrutti(20743) - 131',
#  'Jash Shah(20749) - 134',
#  'Igor OA(20759) - 2313',
#  'jame_smith(20873) - 42',
#  'Haris Michailidis(20875) - 38',
#  'user20880(20880) - 185',
#  'Vineet John(20882) - 62',
#  'aaron(20894) - 29',
#  'jorgemf(20933) - 1115',
#  'edwin(20974) - 669',
#  'nachti(20981) - 12',
#  'BitsInForce(20998) - 26',
#  'kesari(21075) - 97',
#  'Rob(21080) - 364',
#  'Petteri(21125) - 131',
#  'user1787687(21155) - 95',
#  'Seth(21182) - 135',
#  'icl1c(21184) - 160',
#  'user21208(21208) - 66',
#  'MyBushisaNeonJungle(21233) - 81',
#  'lte__(21254) - 8113',
#  'Isbister(21257) - 703',
#  'LuisMi(21260) - 106',
#  'Vladislav Ladenkov(21369) - 154',
#  'Xeqtr(21414) - 1509',
#  'atomsmasher(21430) - 48',
#  'Eduardo Barbaro(21451) - 332',
#  'Ran(21461) - 567',
#  'ColinMac(21468) - 106',
#  'Eka(21471) - 739',
#  'WNG(21473) - 2347',
#  'dagg3r(21500) - 232',
#  'Hanan Shteingart(21596) - 635',
#  'user1813867(21638) - 270',
#  'imba22(21657) - 162',
#  'ranbo(21662) - 20',
#  'Shindou(21676) - 677',
#  'Guru Swaroop(21691) - 103',
#  'Andis(21692) - 193',
#  'user6622314(21746) - 184',
#  'yura(21799) - 100',
#  'Gui42(21804) - 131',
#  'errolflynn(21806) - 318',
#  'user59419(21810) - 111',
#  'vinita(21844) - 58',
#  'Chris(21862) - 296',
#  'Clément Flodrops(21881) - 225',
#  'nn0p(21895) - 62',
#  'tengo(21920) - 96',
#  'lppradeep(21929) - 144',
#  'user21930(21930) - 69',
#  '0x1337(21932) - 31',
#  'Nick Becker(21943) - 342',
#  'user88911(21960) - 329',
#  'user21980(21980) - 339',
#  'NicoDean(21982) - 190',
#  'Drey(21995) - 519',
#  'neha(21998) - 192',
#  'minerals(22012) - 3041',
#  'Dom(22039) - 322',
#  'Train Heartnet(22059) - 377',
#  'BobbyJohnsonOG(23090) - 312',
#  'Hohyun Jung(23091) - 329',
#  'Sharon(23122) - 126',
#  'Haider(23139) - 46',
#  'TechnicalTim(23182) - 44',
#  'Lukas J.(23192) - 105',
#  'Murtuza_07(23208) - 106',
#  'Guy s(23211) - 161',
#  'Andrew(23230) - 1406',
#  'M John(23246) - 161',
#  'atkat12(23262) - 229',
#  'Buzz(23264) - 172',
#  'pghalliday(23277) - 265',
#  'Chen Kinnrot(23278) - 175',
#  'Makarand(23304) - 235',
#  'Peter Ziegler(23422) - 144',
#  'tsttst(23437) - 306',
#  'layser(23478) - 224',
#  'Atte Juvonen(23480) - 1641',
#  'Bruno KM(23511) - 487',
#  'borjab(23521) - 236',
#  'heybati(23571) - 48',
#  'xxxvinxxx(23574) - 236',
#  'AllThingsScience(23600) - 139',
#  'Ildar(23716) - 117',
#  'Daniel Falk(23790) - 233',
#  'Michael Dudalev(23803) - 123',
#  'virilo(23837) - 723',
#  'nnnovice(23853) - 57',
#  'sof(23862) - 120',
#  'Mike(23865) - 151',
#  'sonaam1234(23905) - 203',
#  'Kevin Meier(23909) - 304',
#  'JDL(23911) - 467',
#  'banad(23912) - 67',
#  'NMR(23920) - 1061',
#  'Jason Feng(23983) - 297',
#  'xtluo(24005) - 929',
#  '3x89g2(24024) - 157',
#  'user24040(24040) - 378',
#  'Saksham(24077) - 1339',
#  'Hesham Eraqi(24166) - 312',
#  'GeoMatt22(24240) - 135',
#  'deasmhumnha(24251) - 271',
#  'Georgi Koemdzhiev(24288) - 60',
#  'hps(24290) - 140',
#  'freezingswallow(24303) - 57',
#  'bob bob(24308) - 149',
#  'v78(24346) - 1129',
#  'Alex Nikiforov(24453) - 450',
#  'Amit Gupta(24468) - 35',
#  '42-(24478) - 1435',
#  'pseudo_teetotaler(24530) - 192',
#  'Jim(24550) - 166',
#  'siddshah(24629) - 185',
#  'James(24635) - 288',
#  'netskink(24649) - 59',
#  'farhawa(24657) - 240',
#  'Kiki Rizki Arpiandi(24696) - 2097',
#  'Pedro Alves(24719) - 1003',
#  'Chandresh Gupta(24742) - 399',
#  'sergeyf(24813) - 298',
#  'Itachi(24818) - 1672',
#  'Babak(24837) - 205',
#  'romitheguru(24886) - 161',
#  'Rohola Zandie(24918) - 131',
#  'anshanno(24930) - 1016',
#  'Mat_python(24946) - 64',
#  'Толкачёв Иван(24994) - 365',
#  'Ray(25070) - 71',
#  'Jeremy Bloom(25085) - 119',
#  'user134251(25093) - 157',
#  'Sunčica(25103) - 65',
#  'machineok(25129) - 124',
#  'user25136(25136) - 82',
#  'TSR(25139) - 343',
#  'JoelKuiper(25163) - 2794',
#  'C Child(25167) - 144',
#  'Glorfindel(25180) - 6492',
#  'utengr(25183) - 398',
#  'Hannah(25219) - 149',
#  'giocomai(25222) - 62',
#  'ajcse1(25293) - 21',
#  'Vishalvikram(25301) - 22',
#  'user1766682(25337) - 311',
#  'Thirupathi Thangavel(25345) - 607',
#  'adge(25357) - 185',
#  'kruparulz14(25407) - 96',
#  'philh(25419) - 507',
#  'a25bedc5-3d09-41b8-82fb-ea6c353d75ae(25432) - '
#  '227',
#  'Newbie(25439) - 55',
#  'Afzal(25501) - 178',
#  'suthee(25531) - 47',
#  'Pauline(25537) - 244',
#  'JMoir(25590) - 87',
#  'Avot(25631) - 414',
#  'Caroline(25636) - 107',
#  'Reid Swanson(25637) - 145',
#  'Matt Wenham(25673) - 1300',
#  'lkavenagh(25687) - 51',
#  'Back2Basics(25691) - 215',
#  'Aravind(25741) - 380',
#  'tripleee(25750) - 795',
#  'Shamy(25766) - 340',
#  'Peter(25792) - 32',
#  'Andrey França(25826) - 7',
#  'riss59(25862) - 85',
#  'Towelie(25880) - 128',
#  'Arvind Gurjar(25923) - 65',
#  'Jayaprakash Sundararaj(25976) - 72',
#  'Joe Thomson(25997) - 216',
#  'Mark ellon(26065) - 52',
#  'Mike Campbell(26068) - 0',
#  'Md. Rayhanul Islam(26105) - 178',
#  'JJohnson(26129) - 188',
#  'ClimbsRocks(26173) - 192',
#  'SB2055(26175) - 469',
#  'nsknsl(26181) - 228',
#  'Vespa(26193) - 153',
#  'stats0007(26211) - 898',
#  'Lakshay Sharma(26214) - 63',
#  'AkiRoss(26257) - 1960',
#  'user5779223(26265) - 156',
#  'jhchou(26281) - 450',
#  'Anurag Upadhyaya(26329) - 1197',
#  'DDDD(26334) - 103',
#  'Anonymous(26341) - 105',
#  'Anonymous30(26342) - 154',
#  'Paul(26376) - 154',
#  'Salma(26392) - 185',
#  'Dawid Cz(26408) - 141',
#  'Canovice(26445) - 833',
#  'HuckleberryFinn(26486) - 46',
#  'Xrave(26528) - 69',
#  'Sam(26575) - 139',
#  'NooB8374(26581) - 69',
#  'Til Sander(26591) - 64',
#  'Shankar Narayan G S(26606) - 189',
#  'Ashish Tyagi(26617) - 79',
#  'Alex Yu(26635) - 172',
#  'Slawa(26659) - 117',
#  'PhilippPro(26692) - 145',
#  'c-chavez(26700) - 990',
#  'Stephen(26719) - 174',
#  'sam venu(26775) - 94',
#  'julian(26788) - 1790',
#  'kiliantics(26853) - 484',
#  'Dimuth Tharaka Menikgama(26854) - 189',
#  'Brans(26867) - 66',
#  'user26881(26881) - 202',
#  'David B(26902) - 478',
#  'TPArrow(26903) - 83',
#  'David Groppe(26907) - 227',
#  'G5W(26917) - 3097',
#  'Suraj(26953) - 146',
#  'Chia WJ(26956) - 177',
#  'oxuser(26967) - 197',
#  'EnDorphin(27000) - 410',
#  'azure(27043) - 75',
#  'Andronik(27094) - 37',
#  'PSub(27114) - 5247',
#  'Hunan Rostomyan(27130) - 152',
#  'Daniel(27135) - 571',
#  'dijksterhuis(27144) - 564',
#  'Jean-Phi N(27204) - 87',
#  'Labo(27213) - 619',
#  'Milos(27222) - 199',
#  'Swordsman(27231) - 889',
#  'horaceT(27250) - 5380',
#  'Viral Parekh(27251) - 54',
#  'Noah Chalifour(27286) - 140',
#  'luosha865(27287) - 126',
#  'Tom83B(27313) - 450',
#  'velocirabbit(27322) - 409',
#  'Praise the lord(27330) - 67',
#  'tomaz(27360) - 155',
#  'mark(27435) - 538',
#  'Lucky711(27436) - 103',
#  'Abstractgears(27450) - 452',
#  'DeltaIV(27526) - 1796',
#  'salhin(27537) - 429',
#  'yupbank(27562) - 37',
#  'eamonn(27567) - 33',
#  'Dinesh Kumar(27586) - 113',
#  'Niv Hoffman(27614) - 277',
#  'James Bond(27616) - 1463',
#  'fortune_pickle(27621) - 198',
#  'devdreamer(27680) - 72',
#  'agwah(27683) - 625',
#  'robintibor(27704) - 559',
#  'constiii(27714) - 420',
#  'Martin(27724) - 850',
#  'Alan Wolfe(27729) - 761',
#  'donpresente(27740) - 137',
#  'Pinkesh Badjatiya(27741) - 926',
#  'Paul Siegel(27780) - 233',
#  'Michael(27796) - 132',
#  'R.T.(27822) - 89',
#  'partoa(27823) - 421',
#  'Mark van der Loo(27827) - 91',
#  'Kenny LJ(27838) - 216',
#  'Vlad(27844) - 466',
#  'Saurabh Verma(27872) - 462',
#  'Prayalankar(27873) - 744',
#  'Bob van Luijt(27896) - 103',
#  'striki70(27938) - 78',
#  'Thiedent(27962) - 2029',
#  'I am not Fat(27966) - 698',
#  'rythei(27974) - 160',
#  'A. Kartikay(27976) - 40',
#  'yoav_aaa(27983) - 7371',
#  'Suraj Neupane(27992) - 835',
#  'fab(28021) - 499',
#  'Rishi(28038) - 161',
#  'emrahozkan(28049) - 185',
#  'Secespitus(28125) - 533',
#  'mrbump(28127) - 666',
#  'yusuf(28138) - 399',
#  'user28172(28172) - 107',
#  'AGentleRose(28209) - 599',
#  'Raj(28211) - 364',
#  'Tchotchke(28228) - 95',
#  'JeffThompson(28234) - 219',
#  'FMarazzi(28290) - 61',
#  'Kasia Kulma(28291) - 763',
#  'bru1987(28296) - 310',
#  'Abhishek Pathak(28344) - 615',
#  'Mithrandir(28347) - 77',
#  'user34018(28367) - 692',
#  'theateist(28385) - 2033',
#  'GeneX(28456) - 27',
#  'Zeus(28470) - 302',
#  'Prakash Vanapalli(28482) - 689',
#  'Gabriel Fair(28542) - 483',
#  'derekhh(28556) - 325',
#  'Rott(28572) - 86',
#  'luisfer(28581) - 154',
#  'user1430763(28584) - 231',
#  'christopher(28586) - 347',
#  'S.N.(28611) - 4578',
#  'cbake(28668) - 120',
#  'Alex(28694) - 173',
#  'Jorge Leitão(28714) - 642',
#  'Bryan Lee(28726) - 137',
#  'enterbutton(28732) - 157',
#  'Chris(28802) - 199',
#  'Ben N(28816) - 112',
#  'snirmalkanna(28849) - 11',
#  'sjishan(28868) - 97',
#  'Masum(28881) - 324',
#  'phraniiac(28904) - 277',
#  'renakre(28915) - 430',
#  'melih(28917) - 367',
#  'Manuel(28934) - 116',
#  'vdvaxel(29007) - 53',
#  'Kristin H(29025) - 116',
#  'Roshan Mehta(29033) - 872',
#  'Adam Sypniewski(29083) - 2310',
#  'GGamba(29086) - 458',
#  '4Oh4(29109) - 763',
#  'Thom Kwasky(29116) - 156',
#  'Vincenzo Lavorini(29134) - 6700',
#  'Tyranitar(29138) - 59',
#  'Ethan(29169) - 76691',
#  'fistynuts(29180) - 107',
#  'user1274878(29182) - 58',
#  'VanillaSpinIce(29203) - 813',
#  'CyberDreamer(29206) - 171',
#  'Canardini(29234) - 447',
#  'Actaeonis(29315) - 137',
#  'user1670773(29345) - 162',
#  'AffableAmbler(29353) - 1070',
#  'Arpit Sisodia(29412) - 2715',
#  'sad_943(29422) - 58',
#  'H.H(29434) - 97',
#  'SriA(29435) - 116',
#  'Raizerde(29438) - 161',
#  'Dan Jarratt(29451) - 1180',
#  'Sugarcube Corner(29512) - 115',
#  'Peter Steadman(29513) - 98',
#  'madsthaks(29523) - 69',
#  'Sai(29542) - 36',
#  'James Henderson(29562) - 137',
#  'Shyama(29580) - 1776',
#  'msubbaiah(29601) - 381',
#  'DataAdventurer(29616) - 87',
#  'Anh Phạm(29645) - 37',
#  'William Chou(29690) - 188',
#  'Badger Cat(29692) - 159',
#  'Jo Fisher(29731) - 103',
#  'Arash Jamshidi(29752) - 73',
#  'coderdave(29790) - 804',
#  'Yannis(29799) - 375',
#  'Dan Temkin(29801) - 837',
#  'deltascience(29810) - 528',
#  'echan00(29832) - 40',
#  'Stefano De La Burczymuchito(29862) - 183',
#  'pragmascript(29864) - 100',
#  'Dracarys(29865) - 365',
#  'Dandelion(29878) - 265',
#  'Sinjan Chakraborty(29900) - 68',
#  'Konstantin(29912) - 670',
#  'Alexandre Cortyl(29915) - 153',
#  'Shane(29930) - 97',
#  'Iain Reid(29939) - 374',
#  'Mithun Ghosh(29967) - 438',
#  'John(29999) - 107',
#  'Manik(30006) - 3327',
#  'user30035(30035) - 75',
#  'Alex Firsov(30036) - 1592',
#  'Futuregeek(30039) - 29',
#  'Alireza(30043) - 871',
#  'Ani(30049) - 163',
#  'TasosGlrs(30051) - 417',
#  'Tony Tong(30054) - 154',
#  'Nimtrix(30068) - 186',
#  'Terra Field(30071) - 96',
#  'Aman Mathur(30075) - 348',
#  'Clement(30089) - 144',
#  'intoML(30094) - 179',
#  'Rahul Aedula(30107) - 5348',
#  'PedroMVM(30114) - 95',
#  'Marcin(30121) - 432',
#  'cjMec(30137) - 258',
#  'markbruns(30147) - 858',
#  'dataoverfit(30166) - 655',
#  'Ivan Luchko(30189) - 919',
#  'Kaare(30210) - 678',
#  'simonepi(30240) - 212',
#  'abr_78(30254) - 99',
#  'pietz(30328) - 194',
#  'ac-lap(30363) - 777',
#  'Hypersphere(30389) - 75',
#  'Baktaawar(30406) - 6032',
#  'liangjy(30408) - 805',
#  'user154812(30425) - 464',
#  'user30440(30440) - 105',
#  'Jon Burgess(30450) - 101',
#  'Tool(30482) - 260',
#  'melwin_jose(30492) - 129',
#  'george(30502) - 79',
#  'sh.jeon(30510) - 132',
#  'Vajjhala(30562) - 43',
#  'alpinescrambler(30597) - 340',
#  'Johnnylin(30622) - 71',
#  'M--(30635) - 714',
#  'Shreyak(30637) - 254',
#  'Deepak M(30641) - 94',
#  'neurix(30683) - 535',
#  'SAR(30709) - 133',
#  'Vineet Kothari(30781) - 70',
#  'DSDPA(30802) - 212',
#  'Joshua Mathias(30812) - 326',
#  'end1dream(30817) - 816',
#  'user122358(30856) - 811',
#  'sokokaleb(30859) - 171',
#  'Koh(30864) - 626',
#  'John(30898) - 204',
#  'Subhash Ramesh(30900) - 155',
#  'Kwiebes(30903) - 86',
#  'hinzsa(30914) - 234',
#  'Rahul Chandnani(30921) - 49',
#  'Thomas W(30928) - 2249',
#  'Harris(30953) - 196',
#  'Eumenedies(30964) - 1019',
#  'Biranchi(30986) - 148',
#  'kikim(30994) - 60',
#  'omar(31009) - 299',
#  'Daniel(31012) - 331',
#  'Eddie Eddie(31017) - 437',
#  'ashudeep21(31021) - 42',
#  'Safwan(31027) - 54',
#  'MentatOfDune(31052) - 143',
#  'domino7(31069) - 240',
#  'jasonMmedina(31092) - 506',
#  'iprof0214(31135) - 1499',
#  'Artem Kochnev(31171) - 113',
#  'Sebastian Delgado(31182) - 158',
#  'user7228459(31187) - 28',
#  'yottabytt(31188) - 169',
#  'Halbort(31200) - 465',
#  'SJeon(31208) - 94',
#  'Jeremy Voisey(31216) - 108',
#  'John(31220) - 363',
#  'AlonMln(31229) - 304',
#  'DanJ(31282) - 854',
#  'JNV(31303) - 274',
#  'felixthecar(31307) - 183',
#  'Agraynel Chen(31335) - 242',
#  'astroman(31346) - 845',
#  'Lorenzo Perone(31361) - 63',
#  'Gags(31373) - 69',
#  'Elizabeth Han(31388) - 285',
#  'nz_21(31424) - 116',
#  'StatsSorceress(31434) - 26108',
#  'arjun(31456) - 368',
#  'Mojtaba Komeili(31464) - 278',
#  'Jürgen Zornig(31557) - 179',
#  'LookIntoEast(31590) - 56',
#  'Nisse Engström(31592) - 49',
#  'KevinFergs(31618) - 45',
#  'nikkou(31667) - 112',
#  'JohnnyS(31668) - 409',
#  'parth(31696) - 291',
#  'VansFannel(31726) - 718',
#  'DaveTheAl(31810) - 430',
#  'Eva L(31874) - 79',
#  'Ankur Banerjee(31937) - 63',
#  'SP_(31947) - 55',
#  'Tobias(31948) - 1235',
#  'Yuval Adam(31960) - 549',
#  'zcleghern(31975) - 204',
#  'JoshuaW1990(32002) - 157',
#  'Andrzej H(32048) - 109',
#  'user32104(32104) - 58',
#  'JohnM(32121) - 299',
#  'lengthy_preamble(32153) - 244',
#  'Amous(32161) - 86',
#  'user7666434(32167) - 44',
#  'Shashi Bhushan(32172) - 38',
#  'Grasshopper(32177) - 1020',
#  'SVK(32189) - 139',
#  'Alexander Chervov(32240) - 107',
#  'cosec(32311) - 132',
#  'Chaine(32361) - 762',
#  'kris(32367) - 851',
#  'Namra Saheba(32373) - 106',
#  'Thorra(32398) - 854',
#  'Capie(32490) - 117',
#  'Shaido(32492) - 3559',
#  'datapug(32503) - 232',
#  'Mani(32542) - 90',
#  'Chryb(32543) - 1616',
#  'user32550(32550) - 207',
#  'NeuronQ(32569) - 593',
#  'Keith OYS(32586) - 240',
#  'dknight(32602) - 84',
#  'Ben J. Hawkins(32622) - 406',
#  'Neeleshkumar Srinivasan Mannur(32640) - 151',
#  'Sankalp Garg(32667) - 177',
#  'Max NewSite(32701) - 82',
#  'Aleksey Nozdryn-Plotnicki(32723) - 116',
#  'Brandon(32763) - 35',
#  'Suganthan Raj(32776) - 17',
#  'Nandha(32848) - 183',
#  'Kam(32856) - 117',
#  'Wind P.(32872) - 245',
#  'salient(32875) - 212',
#  'JHS(32906) - 174',
#  'laktak(32916) - 277',
#  'Xu Yuanyuan(32946) - 120',
#  'moksha(32958) - 2341',
#  'Tido(32963) - 2707',
#  'Blazej Kowalski(33018) - 486',
#  'Imran Salam(33040) - 373',
#  'Chris Pillen(33047) - 724',
#  'cjm2671(33058) - 229',
#  'Florent Perez(33091) - 133',
#  'aqua(33095) - 215',
#  'Wassim H(33168) - 94',
#  'MattDs17(33169) - 87',
#  'dirtysocks45(33171) - 1230',
#  'Saeed Esmaili(33188) - 270',
#  'kbrose(33202) - 4872',
#  'CARTman(33226) - 109',
#  'user158(33272) - 373',
#  'B_Real(33298) - 422',
#  'paraba(33333) - 51',
#  'user4309930(33349) - 944',
#  'Jim(33362) - 64',
#  'Spider(33386) - 1050',
#  'Milouga(33390) - 64',
#  'roger(33392) - 107',
#  'acceptedfreak(33417) - 533',
#  'Rohit Mourya(33440) - 273',
#  'albarji(33447) - 678',
#  'John(33451) - 163',
#  'severine(33453) - 389',
#  'Jasmine(33466) - 283',
#  'Sridhar Thiagarajan(33532) - 350',
#  'MrCartoonology(33544) - 159',
#  'Benji Albert(33551) - 10431',
#  'ozn(33567) - 73',
#  'TTF(33584) - 87',
#  'hacker harry(33613) - 147',
#  'tomwesolowski(33643) - 562',
#  'mahnunchik(33668) - 349',
#  'Sébastien Accambray(33672) - 131',
#  'francium87d(33688) - 129',
#  'Josh(33718) - 170',
#  'user66081(33728) - 1319',
#  'ayush gupta(33733) - 132',
#  'Leonard Aukea(33781) - 1478',
#  'CARTMAN(33831) - 140',
#  'Jorge Mendez Mendez(33852) - 142',
#  'Ngoc Anh Huynh(33877) - 175',
#  'Patthebug(33907) - 1201',
#  'Noyes(33921) - 198',
#  'Ramesh(33966) - 384',
#  'user34006(34006) - 170',
#  'darthvader1996(34048) - 414',
#  'Alfamaster(34052) - 185',
#  'Ofer Sadan(34092) - 1026',
#  'Tobi(34130) - 637',
#  'dward4(34158) - 98',
#  'brad(34160) - 171',
#  'ahmedrajput(34177) - 90',
#  'Maurice(34223) - 104',
#  'josh_gray(34253) - 428',
#  'Jake W(34284) - 183',
#  'peterd(35384) - 722',
#  'AMetcalf(35392) - 479',
#  'ocean800(35399) - 1228',
#  'Learner132(35400) - 478',
#  'Kevin(35420) - 1109',
#  'user0(35437) - 21',
#  'Karl(35454) - 177',
#  'eyeballpaul(35461) - 164',
#  'Praveena(35463) - 189',
#  'rhytha(35468) - 158',
#  'Arianna Mussida(35472) - 120',
#  'addcolor(35503) - 1063',
#  'RoyalSwish(35512) - 226',
#  'Aneel(35521) - 33',
#  'sparkdoo(35528) - 231',
#  'vikbehal(35544) - 406',
#  'Bastiaan(35562) - 191',
#  'knightrider(35584) - 242',
#  'Tami(35602) - 146',
#  'S_Ymln(35654) - 51',
#  'Imran.Fanaswala(35701) - 80',
#  'Yash Katariya(35718) - 843',
#  'Alex(35723) - 184',
#  'amanshenoy(35732) - 285',
#  'AxGryndr(35738) - 232',
#  'dumkar(35764) - 175',
#  'Apoorv Bhargava(35807) - 33',
#  'Vitalis Hommel(35814) - 79',
#  'Daddy32(35817) - 536',
#  'Shayan RC(35889) - 131',
#  'hongsy(35902) - 930',
#  'Zhang Yu(35908) - 1183',
#  'user3319400(36943) - 2131',
#  'nKarza(36971) - 234',
#  'Michael M(36977) - 820',
#  'Thomas(37020) - 1383',
#  'Webtopia(37044) - 160',
#  'Kishan Kumar(37063) - 326',
#  'jeweinb(37086) - 75',
#  'jtlz2(37113) - 440',
#  'Sundaresh(37128) - 147',
#  'Michael Dyatchenko(37186) - 126',
#  'LucasRamos(37225) - 189',
#  'haroon7(37259) - 261',
#  'T. Schwartz(37288) - 372',
#  'jd1338(37345) - 1748',
#  'Neoromanzer(37376) - 277',
#  'user8384788(37407) - 862',
#  'nipunasudha(37467) - 80',
#  'Abijith Sankar(37471) - 57',
#  'sariii(37510) - 6686',
#  'lachlan(37516) - 194',
#  'IronEdward(37548) - 15343',
#  'user1419243(37549) - 525',
#  'Vijay(37561) - 99',
#  'agn(37574) - 166',
#  'Suave Bajaj(37646) - 67',
#  'Jan(37718) - 99',
#  'Alex(37736) - 5427',
#  'Morty(37761) - 160',
#  'tangerine7199(37770) - 395',
#  'lostlostlostlostlost(37809) - 363',
#  'Alex(37845) - 84',
#  'mj1261829(37883) - 236',
#  'Ashutosh Khare(37915) - 74',
#  'Jonathan H.(37931) - 168',
#  'Minaj(37991) - 331',
#  'ulitosCoder(37999) - 95',
#  'dkoder(38003) - 239',
#  'JimReno(38019) - 127',
#  'Anthony Pangestu(38063) - 52',
#  'louic(38083) - 2641',
#  'Harshith(38091) - 876',
#  'data science guy(38096) - 3709',
#  'Piaget Modeler(38110) - 462',
#  'acyclicsalmon(38112) - 206',
#  'Physics-Compute(38177) - 143',
#  'AR_(38226) - 279',
#  'balboa(38261) - 399',
#  'rumtscho(38272) - 297',
#  'Tyler L(38302) - 168',
#  'André Christoffer Andersen(38307) - 1477',
#  'Abhishek Niranjan(38308) - 411',
#  '719016(38314) - 97',
#  'Ali(38327) - 157',
#  'Sam Hammamy(38330) - 282',
#  'Yangguang(38419) - 442',
#  'Yuri(38446) - 162',
#  'steve zissou(38460) - 326',
#  'Neil Varnas(38467) - 438',
#  'marcos pozzi(38470) - 26',
#  'Reily Bourne(38477) - 408',
#  'R__A_a_(38487) - 198',
#  'guy(38503) - 209',
#  'Blade(38516) - 450',
#  'Ayman Boustati(38550) - 450',
#  'John D(38608) - 96',
#  'Jason Aller(38616) - 305',
#  'Mathias Mamsch(38630) - 390',
#  'user38663(38663) - 312',
#  'Rambabu Gupta(38673) - 91',
#  'SHAI(38674) - 65',
#  'shalu(38678) - 132',
#  'ZakC(38679) - 133',
#  'astaines(38692) - 268',
#  'SWATHY M NAIR(38695) - 98',
#  'KIToRe(38723) - 156',
#  'Bert Kellerman(38751) - 569',
#  'raghu(38767) - 222',
#  'Shengjie(38791) - 952',
#  "DataD'oh(38864) - 806",
#  'Nauris Dorbe(38884) - 302',
#  'Valentin Calomme(38887) - 15567',
#  'Farewell Stack Exchange(38894) - 0',
#  'Underscore(38903) - 202',
#  'Continue2Learn(38911) - 6448',
#  'aalberti333(38917) - 569',
#  'usman(38983) - 47',
#  'Y0gesh Gupta(39102) - 409',
#  'Jed(39107) - 55',
#  'jlh(39153) - 3',
#  'Richard(39182) - 161',
#  'Bryant (39218) - 84',
#  'Manish Bhaskar Agnihotri(39282) - 31',
#  'surelyourejoking(39286) - 352',
#  'MNLR(39294) - 360',
#  'sevo(39319) - 437',
#  'kdebugging(39363) - 69',
#  'Tarek(39384) - 70',
#  'ChuckP(39425) - 153',
#  'Markus777(39437) - 304',
#  'Kyo(39553) - 92',
#  'Vic(39580) - 265',
#  'Andrew King(39588) - 451',
#  'CezarySzulc(39590) - 1237',
#  'FlorianGD(39673) - 115',
#  'Vladimircape(39706) - 289',
#  'Anatoly Alekseev(39722) - 354',
#  'mallea(39751) - 49',
#  'Frustrated_Student(39755) - 92',
#  'yichudu(39820) - 1341',
#  'pfredriksen(39827) - 71',
#  'BadProgrammer99(39859) - 56',
#  'Ott Toomet(39920) - 116',
#  'kevin(39929) - 1101',
#  'Reza Norouzian(39945) - 106',
#  'redmage123(40026) - 1027',
#  'kRazzy R(40051) - 286',
#  'trolkura(40162) - 434',
#  'thebeancounter(40209) - 151',
#  'Paul Cezanne(40235) - 304',
#  'LexByte(40250) - 61',
#  'Bolboa(40305) - 1118',
#  'JOHN(40343) - 61',
#  'GrizZ(40360) - 576',
#  'Gustavo Lagos(40371) - 190',
#  'Alejandro Rodriguez(40384) - 188',
#  'astudentofmaths(40388) - 167',
#  'Ben(40391) - 279',
#  'Ankit Suri(40407) - 171',
#  'Borg(40415) - 83',
#  'pheeper(40453) - 140',
#  'gms(40457) - 1437',
#  'bwbrowning(40502) - 93',
#  'tbeck(40542) - 64',
#  'glouis(40557) - 524',
#  'Abhinav Gupta(40558) - 108',
#  '3z33etm(40559) - 444',
#  'Sid Prasad(40584) - 265',
#  'Gensoukyou1337(40625) - 286',
#  'Iltl(40659) - 1105',
#  'captainpete(40694) - 39',
#  'Dubukay(40720) - 176',
#  'maooto(40723) - 52',
#  'Isha(40800) - 882',
#  'Abrar(40813) - 116',
#  'Breezecom(40885) - 203',
#  'darksky(40889) - 1016',
#  'dpstart(40908) - 249',
#  'user1887071(40942) - 37',
#  'xiaodai(40951) - 508',
#  'Murat Ozturkmen(40959) - 120',
#  'thovex(40962) - 119',
#  'W641(41024) - 140',
#  'H. Opler(41025) - 199',
#  'Imed(41072) - 3034',
#  'user2614596(41096) - 812',
#  'Krever(41131) - 145',
#  'YJ Kim(41200) - 224',
#  'user3503958(41238) - 134',
#  'meraxes(41254) - 1154',
#  'santosh aditham(41284) - 115',
#  'enumaris(41306) - 748',
#  'Michal_Szulc(41345) - 328',
#  'K48(41366) - 346',
#  'Leonardo Alves(41388) - 231',
#  'Mateusz(41451) - 217',
#  'Adam(41478) - 202',
#  'nlahri(41490) - 95',
#  'bhaskar das(41504) - 441',
#  'Achyuth(41529) - 116',
#  'Alexander Okunev(41535) - 264',
#  'Miguel Miron(41618) - 85',
#  'wit221(41658) - 109',
#  'Josh(41663) - 701',
#  'jeffalltogether(41674) - 391',
#  'ThePassenger(41692) - 2316',
#  'user570593(41699) - 485',
#  'Jesper(41700) - 49',
#  'Jeris Alan(41720) - 177',
#  'wynn(41733) - 302',
#  'Youssef(41737) - 242',
#  'Aniekan Umoren(41755) - 1768',
#  'ldavila07(41785) - 234',
#  'Malcolm(41816) - 50',
#  'Sean(41844) - 287',
#  'myopic(41869) - 518',
#  'Kohn1001(41874) - 137',
#  'DN1(41922) - 854',
#  'Toby(41927) - 101',
#  'Rich(41960) - 50',
#  'bartgras(41965) - 89',
#  'Meiiso(41968) - 799',
#  'Andrej Tihonov(41975) - 223',
#  'Daniel(41990) - 177',
#  'CrankMuffler(42058) - 729',
#  'kv manohar(42061) - 82',
#  'Shane (42200) - 999',
#  'Andy G(42204) - 202',
#  'david guez(42226) - 714',
#  'catethos(42270) - 260',
#  'user3261186(42317) - 161',
#  'ziggystar(42322) - 305',
#  'Mostafa(42335) - 83',
#  'Animate_Ant(42353) - 86',
#  'Hermon Jay(42375) - 77',
#  'RVS(42384) - 81',
#  'zimio(42417) - 552',
#  'antsatsui(42424) - 126',
#  'user4155621(42457) - 218',
#  'azureai(42478) - 270',
#  'user135206(42491) - 88',
#  'anush95(42495) - 81',
#  'Divyanshu Shekhar(42498) - 1995',
#  'JAD(42499) - 71',
#  'Yuval(42500) - 195',
#  'vito yan(42501) - 260',
#  'Dan Erez(42634) - 367',
#  'Sahloul(42637) - 497',
#  'Harry_pb(42648) - 651',
#  'bigdong(42668) - 39',
#  'Shital Shah(42742) - 315',
#  'jay(42771) - 62',
#  'Ognyan(42819) - 47',
#  'Nga Dao(42821) - 921',
#  'EugVal(42832) - 658',
#  'Mattia Colombo(42863) - 255',
#  'Krishna Nevase(42882) - 1795',
#  'hans(42903) - 202',
#  'nirvair(42917) - 101',
#  'Daniel Chepenko(42926) - 1784',
#  'Sanjay(42928) - 159',
#  'Bharath Kumar A(42933) - 104',
#  'Luc Blassel(42951) - 94',
#  'dopexxx(43061) - 314',
#  'Seymour(43110) - 397',
#  'm.elahi(43130) - 102',
#  'snowparrot(43141) - 1380',
#  'Syed Nauyan Rashid(43147) - 788',
#  'Josh(43157) - 44',
#  'pedrogfp(43159) - 290',
#  'user43166(43166) - 169',
#  'Geoffrey Martin(43191) - 173',
#  'gingermander(43215) - 2096',
#  'Daniele Salvatore Albano(43265) - 312',
#  'Elimination(43268) - 219',
#  'Joern Boegeholz(43271) - 269',
#  'TheDahaka(43308) - 168',
#  'freesoul(43309) - 1768',
#  'bcxiao(43358) - 145',
#  'Sebastian(43367) - 606',
#  'Heregoes(43397) - 72',
#  'Bright Chang(43406) - 40',
#  'Andrew Rupert(43429) - 94',
#  'Juan Ramos(43431) - 47',
#  'Sampath Madala(43438) - 1112',
#  'Karthik Shanmukha(43458) - 696',
#  'Mark Yang(43495) - 40',
#  'user5155835(43511) - 444',
#  'Emile D.(43514) - 695',
#  'Oringa(43526) - 150',
#  'Taiko(43532) - 213',
#  'shyam sunder(43541) - 83',
#  'Mane Ko(43548) - 202',
#  'PineNuts0(43635) - 298',
#  'mincorp(43636) - 87',
#  'DrSaravalaki(43637) - 298',
#  'JermaneBoggus(43641) - 600',
#  'akanksha gupta(43668) - 80',
#  'Sam Joe(43680) - 2193',
#  'Haitam Abdoullah(43704) - 81',
#  'Zahi Azmi(43714) - 447',
#  'Ramesh Kumar(43744) - 394',
#  'Harold Castillo(43760) - 164',
#  'Kevin S Lin(43803) - 468',
#  'Ghassan Bati(43812) - 53',
#  'shlady(43846) - 985',
#  'lppier(43855) - 79',
#  'Kye(43856) - 95',
#  'Abhishek Soni(43875) - 203',
#  'seed(43975) - 51',
#  'qutorial(44012) - 18',
#  'Fadi Bakoura(44039) - 4517',
#  'porfgian(44044) - 242',
#  'faraway(44050) - 62',
#  'Jodh Singh(44074) - 382',
#  'Tantaros(44101) - 967',
#  'shimao(44120) - 83',
#  'lknguyen(44187) - 96',
#  'MicRum(44193) - 113',
#  'henk.henkert(44198) - 429',
#  'InquisitivePerson(44214) - 235',
#  'Mateusz J(44250) - 155',
#  'amba88(44271) - 101',
#  'Melchia(44274) - 151',
#  'Jay Speidell(44299) - 4551',
#  'M.F(44305) - 840',
#  'ra1f(44372) - 95',
#  'Nick(44408) - 98',
#  'pascalwhoop(44429) - 932',
#  'user44436(44436) - 142',
#  'DukeLover(44477) - 2544',
#  'jsl(44502) - 114',
#  'Ritesh Satapathy(44519) - 341',
#  'Tina J(44560) - 132',
#  'Nils Schlüter(44648) - 694',
#  'yashhy(44649) - 461',
#  'Pratik Kumar(44673) - 1484',
#  'Srihari(44680) - 5375',
#  'jazib jamil(44708) - 152',
#  'Jon Austin(44712) - 68',
#  'Brandon perez(44739) - 91',
#  'Bloodstone Programmer(44808) - 700',
#  'JeffV(44815) - 131',
#  'Berkay Bulut(44827) - 141',
#  'DBinJP(44857) - 34',
#  'user1189332(44861) - 400',
#  'emaph(44884) - 222',
#  'Oceanic(44901) - 136',
#  'Alan Yu(44949) - 25',
#  'Dan Ellis(44985) - 1967',
#  'Derek Fulton(45060) - 122',
#  'Vikas G Rao(45096) - 130',
#  'Louis Plt(45123) - 121',
#  'Ramya Raj(45147) - 58',
#  'Murtaza(45148) - 87',
#  'TitoOrt(45166) - 7206',
#  'bbennett36(45182) - 1150',
#  'articuno(45183) - 324',
#  'huddy(45185) - 922',
#  'Carlos G. Oliver(45197) - 103',
#  'xiA(45216) - 563',
#  'Nikhil Wagh(45224) - 384',
#  'Umair Rafique(45234) - 114',
#  'Jerry(45237) - 603',
#  'iwillnot(45256) - 87',
#  'J Cena(45262) - 647',
#  'malocho(45271) - 93',
#  'nightmarish(45297) - 453',
#  'mtngt(45299) - 455',
#  'Guseyn Gadirov(45317) - 139',
#  'SSY1291(45351) - 160',
#  'sapal6(45356) - 485',
#  'Indira Batubara(45361) - 96',
#  'bradS(45374) - 8844',
#  'user5722540(45385) - 410',
#  'Amanda Spolti(45389) - 125',
#  'Kal21(45391) - 199',
#  'Kailegh(45431) - 717',
#  'Grw Křemílek(45440) - 167',
#  'sunsets(45485) - 189',
#  'Sana Afreen(45488) - 154',
#  'saeed masoomi(45494) - 469',
#  'Elias Strehle(45507) - 18138',
#  'rayanisran(45515) - 658',
#  'Santhosh(45545) - 1122',
#  'Sameer Choudhary(45548) - 108',
#  'alex(45572) - 94',
#  'myseun(45573) - 180',
#  'xuzhijiang(45600) - 95',
#  'A. G.(45615) - 1125',
#  'HP Williams(45635) - 127',
#  'H.Rehman(45698) - 388',
#  'user45739(45739) - 106',
#  'Anne Bierhoff(45747) - 193',
#  'MerklT(45756) - 272',
#  'MaxouMask(45762) - 287',
#  'goncalopp(45803) - 692',
#  'Aditya(45804) - 182',
#  'koryakinp(45821) - 4190',
#  'bbarroso(45845) - 384',
#  'alexprice(45852) - 440',
#  'karun_r(45872) - 162',
#  'gabboshow(45913) - 639',
#  'Ashok DS(45930) - 325',
#  'raton roguille(45957) - 75',
#  'George(45965) - 111',
#  'user45996(45996) - 582',
#  'Rajeev Motwani(46007) - 722',
#  'WillisJohnson(46082) - 77',
#  'Tom(46107) - 3390',
#  'Matt Findlay(46120) - 130',
#  'Achraf Oussidi(46123) - 1163',
#  'davidhin(46129) - 702',
#  'CP3O(46164) - 326',
#  'Moush613(46165) - 120',
#  'Houcine Amraoui(46174) - 308',
#  'stanley4430(46192) - 117',
#  'user3602666(46197) - 209',
#  'Jose Manuel Albornoz(46212) - 149',
#  'Will P.(46231) - 168',
#  'Indominus(46282) - 502',
#  'Aliaksandr Nazarau(46284) - 902',
#  'user46289(46289) - 180',
#  'gurvinder372(46293) - 454',
#  'RSSharma(46301) - 483',
#  'Pablo Messina(46305) - 4857',
#  'Roofkiller(46308) - 71',
#  'user134132523(46309) - 760',
#  'Bs He(46315) - 245',
#  'HugoMailhot(46319) - 408',
#  'li x(46327) - 884',
#  'Amresh Giri(46334) - 125',
#  'Muralidhar A(46360) - 1266',
#  'Taha(46407) - 164',
#  'Christopher Costello(46424) - 84',
#  'Zach(46426) - 203',
#  'Wall-E(46472) - 111',
#  'rohan23(46504) - 345',
#  'Borhan Kazimipour(46505) - 3659',
#  'tarun14110(46522) - 61',
#  'Johnathan Brown(46523) - 746',
#  'Aditya(46535) - 503',
#  'cvonsteg(46537) - 330',
#  'Fernando Irarrázaval G(46543) - 136',
#  'Amir(46590) - 1566',
#  'Dominik(46616) - 218',
#  'Kleyn(46617) - 105',
#  'isra abuhasna(46648) - 89',
#  'johnnewbie(46654) - 138',
#  'Rangerix(46671) - 117',
#  'Pardhu(46672) - 106',
#  'Universalis0(46748) - 520',
#  'Zachary Drake(46756) - 41',
#  'wubzorz(46779) - 224',
#  'kawingkelvin(46782) - 515',
#  'Shahbaz(46810) - 34',
#  'Oğuz Şerbetci(46848) - 174',
#  'jchaykow(46886) - 995',
#  'Luka(46924) - 193',
#  'TTZ(46933) - 193',
#  'Underminer(46949) - 600',
#  'ralien(46981) - 865',
#  'ivegotaquestion(46982) - 32',
#  'Kay Lamerigts(47011) - 393',
#  'Sierra Oscar(47101) - 381',
#  'Fredrik Boston Westman(47169) - 394',
#  'woodgate(47184) - 229',
#  'user73749(47202) - 122',
#  'Yohan F(47219) - 27',
#  'user1253952(47257) - 303',
#  'snow(47276) - 103',
#  'Anandologist(47286) - 1508',
#  'maxisme(47290) - 158',
#  'Turo(47322) - 170',
#  'אבנר יעקב(47366) - 89',
#  'Daniel Rasmuson(47374) - 207',
#  'John(47380) - 3240',
#  'amandacerry(47390) - 31',
#  'Alex(47442) - 222',
#  'Pavel Savine(47488) - 7391',
#  'Tiphaine(47497) - 862',
#  'Peehay(47526) - 266',
#  'Chenying Gao(47533) - 210',
#  'Bernice Abel(47540) - 67',
#  'Silas Berger(47561) - 1171',
#  'John M.(47562) - 526',
#  'user112237(47568) - 187',
#  'sousdev(47570) - 379',
#  'sspp(47600) - 481',
#  'Hung Hoang(47659) - 58',
#  'Harini Vaidyanath(47698) - 154',
# ...
#  'Rugbrød(69904) - 115',
#  'Ali Faraz(69940) - 288',
#  'user84592(69959) - 122',
#  'Djaik Navidson(69972) - 1159',
#  'Yo B.(69994) - 590',
#  'KRL(70021) - 779',
#  'Vipul Gaurav(70037) - 752',
#  'eugene(70073) - 842',
#  'ShowyTool(70097) - 210',
#  'Blitva(70126) - 288',
#  'user70145(70145) - 1682',
#  'Karsten(70153) - 60',
#  'Universal_learner(70164) - 908',
#  'Mouad Alami(70220) - 217',
#  'Mcrey Fonacier(70224) - 87',
#  'user8238644(70227) - 500',
#  'Edward Alhanoun(70235) - 325',
#  'davide445(70274) - 106',
#  'Jakub Czakon(70330) - 119',
#  'Jinwoo Lee(70343) - 85',
#  'Luiz Amaral(70346) - 765',
#  'Hedd(70397) - 148',
#  'user1714647(70420) - 252',
#  'Rahul(70454) - 165',
#  'Alperen Kantarcı(70487) - 120',
#  'Dravidian(70520) - 348',
#  'Windstorm1981(70539) - 184',
#  'Andreas Mastronikolis(70542) - 73',
#  'user3613025(70555) - 2933',
#  'Johnny(70576) - 102',
#  'anna(70607) - 287',
#  'TheJokerAEZ(70641) - 819',
#  'Shyam Kishor(70647) - 72',
#  'GapPs(70657) - 154',
#  'Artem(70660) - 98',
#  'oppia04(70666) - 125',
#  'Tatyana(70688) - 362',
#  'Carl Dombrowski(70709) - 803',
#  'DonCappie(70716) - 251',
#  'Salmon(70725) - 260',
#  'Arma_91(70747) - 79',
#  'Akshit jain(70749) - 1036',
#  'Little Helper(70750) - 136',
#  'A Berry(70782) - 412',
#  'Kermit(70802) - 532',
#  'Unrefracted_Hooloovoo(70808) - 482',
#  'Wikked(70814) - 89',
#  'LiuHao(70823) - 67',
#  'Shubh(70832) - 164',
#  'B.K(70910) - 678',
#  'user70920(70920) - 237',
#  'Sameer Kesava(70936) - 697',
#  'Salman Tabatabai(70947) - 128',
#  'MNA(70962) - 608',
#  'Denny(70980) - 584',
#  'Aishwarya patil(70987) - 304',
#  'michael scolfield(70990) - 516',
#  'hojusaram(70993) - 127',
#  'Zahid Ahmed(70994) - 1332',
#  'Swapnil Pote(71006) - 1965',
#  'william valido(71038) - 288',
#  'TheCG(71118) - 58',
#  'Brady Gilg(71140) - 378',
#  'Nikhil Goyal(71158) - 81',
#  'JackWills(71172) - 489',
#  'Takwa(71199) - 68',
#  'biryulin04(71201) - 122',
#  'ag_ojo(71210) - 47',
#  'Peter Arsenault(71212) - 139',
#  'Juan Esteban de la Calle(71218) - 26751',
#  'jake9115(71222) - 471',
#  'Darpan Dahal(71240) - 251',
#  'Harikrishnamv(71241) - 45',
#  'Raymond Kwok(71243) - 72',
#  'Ben(71246) - 974',
#  'Fred E(71274) - 146',
#  'Kechen(71283) - 157',
#  'giser_yugang(71301) - 291',
#  'user3839833(71310) - 108',
#  'Helge(71333) - 198',
#  'user6118986(71348) - 297',
#  'shammpa(71353) - 104',
#  'Zeruno(71357) - 622',
#  'Joshua(71359) - 299',
#  'Nicolas(71361) - 78',
#  'Sanjeev Ram(71374) - 62',
#  'joshvarial(71375) - 306',
#  'arystarch(71401) - 174',
#  'daxterss(71418) - 139',
#  'Extermis(71441) - 713',
#  'Peter(71442) - 36339',
#  'James Mayfield(71443) - 115',
#  'Kartikeya Sharma(71464) - 613',
#  'Babak.Abad(71504) - 211',
#  'Nixel(71515) - 981',
#  'Space Ghost(71538) - 483',
#  'Tong  Lin(71567) - 838',
#  'Benj(71581) - 620',
#  'Eva(71585) - 180',
#  'Nadjmeddine Boudjellal(71611) - 74',
#  'MrL(71630) - 126',
#  'Bhupesh_decoder(71637) - 1231',
#  'qzaq(71643) - 132',
#  'Giang Nguyễn(71648) - 276',
#  'Giulia Cassarà(71661) - 84',
#  'dmahata(71667) - 44',
#  'Ismael EL ATIFI(71675) - 4032',
#  'Alisher Muhamed(71778) - 65',
#  'Ajith Madhav(71791) - 52',
#  'JamieA(71805) - 223',
#  'Katelyn(71811) - 112',
#  'Frank W.(71832) - 108',
#  'Kinkade(71838) - 436',
#  'J Doe(71855) - 113',
#  'disney82231(71861) - 878',
#  'dfvc(71863) - 34',
#  'Ives Rodriguez(71868) - 106',
#  'mikazz(71884) - 968',
#  'Alex Deft(71918) - 494',
#  'Juan C(71949) - 128',
#  'Sm1(71952) - 930',
#  'aoj(71964) - 1455',
#  'HLeb(71979) - 701',
#  'Niccolò Veronesi(72022) - 517',
#  'Miguel Angel(72024) - 149',
#  'Shamoon Ahmad(73042) - 344',
#  'Kale-ab Tessera(73060) - 67',
#  'Migara(73064) - 177',
#  'Dick(73086) - 107',
#  'Sundeep Pidugu(73114) - 779',
#  'pragun(73127) - 368',
#  'med(73133) - 107',
#  'Stan Maydan(73147) - 158',
#  'Alex F(73150) - 2472',
#  'J. Williams(73207) - 270',
#  'Houssam(73227) - 207',
#  'MathematicalML(73231) - 116',
#  'ѕняєє ѕιиgнι(73251) - 639',
#  'vineela karnati(73269) - 538',
#  'user2726192(73293) - 385',
#  'Josiah L.(73298) - 1358',
#  'Ashutosh Eve(73329) - 288',
#  'user3444337(73364) - 88',
#  'free_road(73399) - 659',
#  'user73423(73423) - 585',
#  'ninji(73428) - 489',
#  'leo d torchia(73448) - 115',
#  'CoderEnthusiast(73465) - 86',
#  'Jackdaw(73478) - 311',
#  'user73501(73501) - 106',
#  'Nikita Zavyalov(73518) - 114',
#  'Scott Severance(73534) - 360',
#  'user73536(73536) - 76',
#  'brennn(73547) - 706',
#  'StefanKolek Martinez de Azagra(73573) - 202',
#  'Polina(73579) - 193',
#  'Ansh(73600) - 136',
#  'hcooh(73601) - 112',
#  'Muhammad Fasiurrehman Sohi(73607) - 874',
#  'FirePower(73613) - 523',
#  'Ross Kohler(73620) - 188',
#  'Kirito Solo(73621) - 155',
#  'Milan(73636) - 1545',
#  'Grothendeeeeck(73641) - 264',
#  'Pigna(73645) - 364',
#  'NaveganTeX(73650) - 1010',
#  "I_Don't_Code(73654) - 235",
#  'raullalves(73655) - 70',
#  'JSH(73665) - 123',
#  'Jacky(73672) - 82',
#  'Fareishuge(73724) - 523',
#  'Ann(73726) - 128',
#  'user73786(73786) - 64',
#  'Zhenkai(73821) - 252',
#  'user3792245(73828) - 455',
#  'RaJa(73848) - 245',
#  'sanwall(73860) - 30',
#  'Ping (73861) - 350',
#  'Siddhant Singh(73865) - 89',
#  'JayFossil(73903) - 72',
#  'xxyy(73911) - 599',
#  'Joe(73956) - 85',
#  'nitrogen(73965) - 1011',
#  'Ajay jadhav(73972) - 103',
#  'Marco Caglia(73981) - 324',
#  'Thenerd(73983) - 125',
#  'hey0(73996) - 239',
#  'Jason Mathews(74001) - 41',
#  'Antares42(74013) - 337',
#  'Tim Weah(74018) - 275',
#  'GoBackess(74019) - 249',
#  'Vipul K Reddy(74036) - 953',
#  'Jim the fourth(74040) - 1188',
#  'Daniel Robert-Nicoud(74050) - 356',
#  'Taylor(74068) - 398',
#  'Yenaled(74073) - 83',
#  'Assaf(74091) - 213',
#  'Syenix(74118) - 87',
#  'mkf(74167) - 238',
#  'TheSugoiBoi(74169) - 310',
#  'Jonny(74172) - 121',
#  'tensorblow(74183) - 169',
#  'Anakin87(74184) - 288',
#  'John Tenenbaum(74213) - 79',
#  'Geza Kerecsenyi(74214) - 5486',
#  'Lenka(74245) - 73',
#  'Tamas(74248) - 646',
#  'Guilherme Marques(74267) - 143',
#  'Muhammad Hanif Sarwari(74281) - 147',
#  'Falc14(74301) - 382',
#  'Vladimir Nabokov(74304) - 63',
#  'Ringleader(74322) - 146',
#  'farid (74339) - 108',
#  'seeker(74354) - 130',
#  'kayak(74366) - 153',
#  'mober(74434) - 111',
#  'Sayooj Balakrishnan(74439) - 88',
#  'Ariel Serranoni(74468) - 518',
#  'powerbioverflow(74521) - 82',
#  'Vincent Brisse(74532) - 67',
#  'King(74593) - 696',
#  'The_Chicken_Lord(74617) - 1018',
#  'Hao Xu(74632) - 142',
#  'raffamaiden(74649) - 593',
#  'Cihan Barış(74680) - 200',
#  'Effesian(74707) - 290',
#  'ayesha(74760) - 311',
#  'bptan(74772) - 116',
#  'christk(74778) - 104',
#  'AgentMoe(74811) - 110',
#  'NightFury(74838) - 76',
#  'Benjamin(74867) - 26',
#  'Dennis(74871) - 651',
#  'Bilgin(74894) - 1813',
#  'C. Rutscher(74906) - 47',
#  'nish1013(74912) - 128',
#  'Liam Ferris(74923) - 242',
#  'Peter Schwarz(74980) - 147',
#  'Josef(75015) - 406',
#  'newbie(75017) - 45',
#  'moh_isa(75025) - 149',
#  'Caaarlos(75084) - 57',
#  'Ankit Patel(75090) - 155',
#  'Stephen Collins(75102) - 761',
#  'Hunter Knighton(75107) - 54',
#  'Perry(75120) - 120',
#  'Lan Phuong(75147) - 105',
#  'Oxbowerce(75157) - 150',
#  'moon(75206) - 89',
#  'shamwow(75215) - 390',
#  'Chandrashekhar Patil(75217) - 187',
#  'Maura(75224) - 120',
#  'wojteo(75232) - 536',
#  'tim(75241) - 38',
#  'user75249(75249) - 118',
#  'user75273(75273) - 63',
#  'HeroMonk(75276) - 112',
#  'Angela(75285) - 305',
#  'guest(75289) - 63',
#  'solveForX(75298) - 97',
#  'Paul92(75335) - 1419',
#  'bas domburg(75350) - 33',
#  'Nogi7(75358) - 1039',
#  'Bence Szabó(75369) - 508',
#  'Pedro Penzuti Pacheco(75374) - 789',
#  'william(75377) - 45',
#  'Adrian Negru(75382) - 83',
#  'NickE(75383) - 249',
#  'James Liu(75390) - 216',
#  'letmaik(75425) - 40',
#  'Pet(75430) - 101',
#  'magu_(75431) - 216',
#  'Wouter Vandenputte(75432) - 68',
#  'Yehuda(75445) - 250',
#  'Jiayu(75455) - 302',
#  'user2015915(75468) - 469',
#  'nice little blood smear(75473) - 130',
#  'Nithin G A(75483) - 76',
#  'Robin(75492) - 56',
#  'D. Christopher(75511) - 250',
#  'Beherit(75523) - 1461',
#  'Mat(75528) - 1196',
#  'Cihan Dogan(75547) - 67',
#  'BbJug(75570) - 212',
#  'user253546(75586) - 39',
#  'Gilles G(75588) - 209',
#  'harshtiwari(75606) - 81',
#  'Richard(75646) - 237',
#  'imageimbalanceuser(75657) - 281',
#  'zalman.brosh(75674) - 304',
#  'Mehdi bmp(75681) - 186',
#  'Dhiren Mehta(75688) - 108',
#  'randomizer0000(75701) - 242',
#  'Soumee(75703) - 847',
#  'CovertKoala(75716) - 102',
#  'Snehal Raj(75740) - 244',
#  'imguessing(75750) - 90',
#  'Tom Z(75761) - 139',
#  'davislf2(75829) - 102',
#  'Keith(75837) - 321',
#  'lsusr(75839) - 342',
#  'Quasar(75841) - 188',
#  'Boogey_man(75842) - 584',
#  'thushv89(75849) - 529',
#  'user9060036(75851) - 115',
#  'Sca(75868) - 151',
#  'TheLastPixie(75912) - 2053',
#  'Hun Cho(75934) - 354',
#  'umar(75941) - 100',
#  'Nissim(75942) - 80',
#  'Adeetya(75956) - 178',
#  'Collin Cunningham(75974) - 198',
#  'Senya(75981) - 77',
#  'Delan(76001) - 76',
#  'Naveed(76007) - 48',
#  'Biel43(76020) - 125',
#  'Saeed Ahmad(76031) - 225',
#  'kee(76047) - 243',
#  'Dawn17(76062) - 231',
#  'Medz Benz(76064) - 96',
#  'Lei Xun(76074) - 365',
#  'loadbox(76087) - 738',
#  'George Namara(76089) - 161',
#  'Kushani5j(76093) - 167',
#  'ŁukaszW.pl(76098) - 202',
#  'tharun___ data enthusiast(76129) - 374',
#  'taga(76137) - 456',
#  'Tresor Koffi(76138) - 32',
#  'Hunter Dyer(76164) - 255',
#  'clarke444(76169) - 179',
#  'vanetoj(76177) - 536',
#  'vignesh_md(76202) - 196',
#  'ccouturi(76209) - 609',
#  'tawab_shakeel(76229) - 33',
#  'Oluwafemi E. Ogundare(76245) - 202',
#  'khyati(76263) - 141',
#  'Sam(76276) - 154',
#  'sebmal(76284) - 245',
#  'Chocolate(76291) - 610',
#  'user276806(76306) - 191',
#  'interwebjill(76311) - 572',
#  'Ken Kim(76321) - 334',
#  'Caterpillaraoz(76329) - 155',
#  'MSS(76333) - 147',
#  'Anu S(76343) - 437',
#  'Balu(76417) - 118',
#  'Guissous Allaeddine(76422) - 5140',
#  'anjama(76424) - 426',
#  'SFQ(76435) - 32',
#  'maltodextrin(76444) - 136',
#  'Ellen Sheldon(76481) - 76',
#  'Timofey(76495) - 773',
#  'Yuq Wang(76511) - 182',
#  'sherek_66(76523) - 807',
#  'keychain(76527) - 152',
#  'Machupicchu(76530) - 2293',
#  'deep_learner(76560) - 545',
#  'Hunnam (76601) - 540',
#  'CarlosUziel(76631) - 1357',
#  'LizzAlice(76641) - 1313',
#  'studentcoder(76675) - 204',
#  'clems(76692) - 148',
#  'Khitish Mohanty(76697) - 190',
#  'Brad Wheeler(76702) - 102',
#  'Dibakor Barua(76706) - 192',
#  'ludan(76715) - 273',
#  'Aditya(76730) - 84',
#  'ruhig brauner(76762) - 216',
#  'ryh(76784) - 51',
#  'vpz(76787) - 146',
#  'fhaase(76794) - 617',
#  'SMS(76825) - 252',
#  'EzeEst(76833) - 38',
#  'user12424(76837) - 48',
#  'celiebrockett(76841) - 296',
#  'MVP(76845) - 71',
#  'Shiva(76923) - 221',
#  'Mohan Raj Raja(76930) - 111',
#  'Parmita biswas(76932) - 348',
#  'Jo Makintash(76934) - 121',
#  'Tom Kealy(76939) - 147',
#  'ranahd(76948) - 96',
#  'Johannes Schmidt(76964) - 198',
#  'im_so_meta_even_this_acronym(76988) - 360',
#  'Divyanshu Rathi(76992) - 199',
#  'Vernica Jain(77003) - 348',
#  'omega(77023) - 836',
#  'go easy(77044) - 134',
#  'Justin Messi(77054) - 203',
#  'Prasanth pedda(77075) - 150',
#  'briansol(77092) - 57',
#  'ten do(77102) - 785',
#  'NomNomNom(77110) - 31',
#  'bchoiNY(77121) - 114',
#  'thewhitetie(77122) - 82',
#  'user10351235(77143) - 97',
#  'Zur Luria(77144) - 101',
#  'Rafa L(77150) - 58',
#  'George(77152) - 144',
#  'Parth Sindhu(77169) - 263',
#  'Pavithran Iyer(77173) - 487',
#  'arjun(77190) - 77',
#  'Harsha Kokel(77224) - 30',
#  'Adam(77250) - 124',
#  'David Buzatu(77270) - 102',
#  'Apple_786(77276) - 209',
#  'Zarif(77346) - 277',
#  'manuel mourato(77352) - 441',
#  'Sebastian(77377) - 2601',
#  'AWhite(77382) - 119',
#  'Mark(77393) - 788',
#  'Nandha(77418) - 31',
#  'gucciontoast(77424) - 399',
#  'user3426943(77458) - 118',
#  'YSP(77484) - 450',
#  'feeeper(77499) - 85',
#  'C Murphy(77505) - 112',
#  'myml(77508) - 229',
#  'zeddar(77545) - 149',
#  'Anton S(77557) - 592',
#  'Karen Lie(77593) - 124',
#  'StukedCoder(77612) - 103',
#  'Rahul Poddar(77614) - 158',
#  'Nirmalya Misra(77618) - 449',
#  'Shubham(77619) - 48',
#  'Thomas(77667) - 148',
#  'rajarshi(77677) - 99',
#  'Suresh P(77691) - 47',
#  '9009.monkey(77719) - 697',
#  'Tauseef Ahmad(77732) - 115',
#  'tre95(77742) - 356',
#  'Sean Mirchi(77743) - 1395',
#  'MartykQ(77748) - 97',
#  'Darren Ng(77751) - 668',
#  'Ambar Walia(77753) - 357',
#  'Stephen Reynolds(77766) - 55',
#  'Kushal Dave(77780) - 55',
#  'user77792(77792) - 458',
#  'Jerry Kross(77803) - 314',
#  'drh0use(77809) - 186',
#  'Ubhi(77821) - 242',
#  'EArwa(77831) - 218',
#  'Python bee(77860) - 173',
#  'heather(77866) - 235',
#  'PDPDPDPD(77927) - 134',
#  'Aaron Cao(77936) - 173',
#  'Mocas(77942) - 354',
#  'FelizNaveedad(77960) - 260',
#  'FremyCompany(77970) - 214',
#  'anagha s(77982) - 164',
#  'Stef(78004) - 592',
#  'Sam123(78010) - 108',
#  'Sushanth(78027) - 106',
#  'Notna(78030) - 421',
#  'srini(78038) - 93',
#  'dulo Collins(78039) - 198',
#  'DS_GB(78047) - 189',
#  'minion_1(78059) - 410',
#  'MDubs(78135) - 136',
#  'Alter(78143) - 476',
#  'Hadi GhahremanNezhad(78192) - 206',
#  'khwaja wisal(78207) - 4062',
#  'Shoorty(78233) - 176',
#  'WhiteDillPickle(78250) - 118',
#  'waploaj(78253) - 66',
#  'user10796158(78269) - 1983',
#  'Andrew Bury(78270) - 61',
#  'Jheni Gonsalves(78279) - 3459',
#  'Hello Mellow(78284) - 336',
#  'felix Antony(78334) - 240',
#  'mburakergenc(78346) - 99',
#  'Naeem(78378) - 149',
#  'arxoft(78392) - 157',
#  'jclge(78402) - 161',
#  'Xiaohan Du(78408) - 305',
#  'user134068(78435) - 240',
#  'Alex Yin(78472) - 59',
#  'Ankit DEsai(78502) - 46',
#  'Gozie(78512) - 47',
#  'stannis(78514) - 129',
#  'malwr(78519) - 131',
#  'Максим Фрейд(78580) - 43',
#  'Guneykan Ozkaya(78582) - 46',
#  'Inquist(78733) - 77',
#  'user48878(78766) - 401',
#  'Jakob Drusany(78798) - 2421',
#  'John F(78816) - 185',
#  'A_the_kunal(78821) - 120',
#  'ytte(78838) - 114',
#  'Vishwanath Gubba(78849) - 97',
#  'Kevin Hoopes(78853) - 328',
#  'Angus(78857) - 57',
#  'Curious(78867) - 881',
#  'Michael Gardner(78876) - 151',
#  'sara alsaif(78924) - 116',
#  'Colin C(78929) - 494',
#  'skywalkerdk(78955) - 388',
#  'cookiedealer(78987) - 114',
#  'anuj tyagi(79016) - 250',
#  'Manish Kumar(79022) - 85',
#  'huma rehman(79036) - 1481',
#  'abhishek(79038) - 270',
#  'Jonathan Hedger(79046) - 158',
#  'Tanvir Hossain(79053) - 124',
#  'tbone(79057) - 503',
#  'R. Shubham(79062) - 660',
#  'Tristan HB(79078) - 186',
#  'Akash(79085) - 489',
#  'Ellen Voorhees(79100) - 26',
#  'JustusM(79110) - 688',
#  'achandra03(79124) - 544',
#  'user79129(79129) - 53',
#  'neverevernever(79142) - 147',
#  'Moeinh77(79160) - 752',
#  'edan patt(79176) - 183',
#  'Mohanad Y.(79177) - 245',
#  'Aeryan(79186) - 608',
#  'Russell Gould(79193) - 290',
#  'Bartek(79199) - 434',
#  'Navdeep(79262) - 1141',
#  'Carlos Pinzón(79267) - 40',
#  'Maria Lavrovskaya(79297) - 190',
#  'Ishan Babbar(79322) - 551',
#  'Priyanshu Khullar(79328) - 25',
#  'talia frasat(79374) - 624',
#  'Tillus(79375) - 138',
#  'Marcel Moosbrugger(79409) - 91',
#  'Pavan(79416) - 369',
#  'Jason Cheung(79451) - 45',
#  'VRaina(79462) - 123',
#  'John Davis(79465) - 73',
#  'user_12(79490) - 129',
#  'Gurrako(79498) - 138',
#  'Brent Cocu(79536) - 253',
#  'Matt Keller(79538) - 325',
#  'random_username(79546) - 186',
#  'user3371198(79547) - 287',
#  'Nicholas Taylor(79559) - 158',
#  'hhsecond(79565) - 147',
#  'Shivkumar Nadar(79566) - 98',
#  'Mingu Hyun(79581) - 63',
#  'Bálint Kőszegi(79588) - 41',
#  'bemzoo(79600) - 201',
#  'Salman K(79603) - 61',
#  'Alan Yang(79606) - 128',
#  'leak(79610) - 122',
#  'Ben(79636) - 54',
#  'Kaja. Gowtham(79643) - 39',
#  'Francesco Cariaggi(79648) - 580',
#  'Dr. H. Lecter(79659) - 579',
#  'Tushar Seth(79679) - 393',
#  'Dustin(79721) - 148',
#  'StringsAndThings(79739) - 282',
#  'Neeraj Sharma(79753) - 165',
#  'khiem nguyen trong(79775) - 121',
#  'Gaurav Koradiya(79777) - 186',
#  'Mcßendzåmïn Xiån Luboya Jr.(79906) - 102',
#  'Cogita Semper(79945) - 244',
#  'MachuPichu(79947) - 280',
#  'Mina Younan(79994) - 252',
#  'SuperSimplePimpleDimple(80015) - 291',
#  'Ahmad(80016) - 96',
#  'ihf(80030) - 38',
#  'Ali Kılınç(80032) - 191',
#  'user882763(80085) - 209',
#  'Guillem(80117) - 7',
#  'Ganesh Kannan K S(80118) - 45',
#  'Aishwarya A R(80129) - 142',
#  'Satvik Golechha(80140) - 122',
#  'Eric Beckwith(80187) - 31',
#  'cesko80(80192) - 302',
#  'Yash Maurya(80199) - 207',
#  'FrankK(80219) - 178',
#  'Alexey(80249) - 153',
#  'Jo_Gisbert(80252) - 529',
#  'lucifer(80264) - 142',
#  'Perl(80285) - 676',
#  'fibble(80325) - 1186',
#  'Hardeep Singh(80331) - 31',
#  'M. Merida-Floriano(80338) - 105',
#  'Tyler(80363) - 102',
#  'pooja singhal(80382) - 67',
#  'deepthi senthil(80405) - 20',
#  'Spencer Kraisler(80417) - 201',
#  'aname(80445) - 305']

# %% [markdown]
# ### Reading in Comments.xml into a RDD

# %%
CommentsXmlData = ET.parse('../data_files/datascience/Comments.xml')
Comments = sc.parallelize([item.attrib for item in CommentsXmlData.getroot()])
print('No of Records in Comments.xml : ',Comments.count())
print('Sample Record :')
pprint(Comments.first(),width=50)
# Out:
# No of Records in Comments.xml :  41722
# Sample Record :
# {'CreationDate': '2014-05-14T00:23:15.437',
#  'Id': '5',
#  'PostId': '5',
#  'Score': '9',
#  'Text': 'this is a super theoretical AI '
#          'question. An interesting discussion! '
#          'but out of place...',
#  'UserId': '34'}

# %% [markdown]
# ### 5) GRADUATE STUDENTS: Using the users.xml, comments.xml and PostHistory.xml files, produce a single file that includes the following information: DisplayName, Number of Comments, total Score and Number of posts. This file should have the users (DisplayName) sorted by score, descending from higher to lower. (40 points)
#
# We can divide this question into 4 components :
# * Getting the Summary of Total Score and Number of Comments by User
# * Joining the Summary of Comments with Summary of Posts from previous question with key as 'UserId'
# * Joining the resultant of previous step to 'UserDisplayName' RDD to get the Display names for all users.
# * Sorting the Final dataset consisting of User ID, Display Name, Total Score, Number of comments, Number of Posts by using the Total Score in descending

# %% [markdown]
# For the first 2 steps : (Please look at code for format of data at each step)
# * We can start by taking the fields UserId, Score and Arbitrary '1'(for comment count) into a new RDD 'CommentsScore'
# * We will apply reduceByKey to 'CommentsScore', to get a summary of Total Score and No of comments by UserID
#
#
# * Now we will join the reduced Comments RDD with the reduced Post Count RDD
#     * We use a 'fullOuterJoin' for this purpose because, there could be users who have made comments but have never made any posts and vice versa.
#     * But since we are using a 'fullOuterJoin' we can expect 'None' values where a User might have missing values in either of the RDDs.
#     * We defined a function 'map_null' to handle all those 'None' values, by filling the missing values with '0's and also to convert the data into a single key,value tuple for further operations.

# %%
CommentsScore = Comments.map(lambda line : 
                             (line.get('UserId',"No User ID"),
                              (int(line.get('Score',0)),1)))
#Format - (UserID,(Score,1))

ScoreByUser = CommentsScore.reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1]))
#Format - (UserID,(Total Score,No. of Comments))

#Function to handle the Null values because of fullOuterJoin
def map_null(line) :
  arr = []
  for x in line :
    if x is not None :
      for y in x :
        if y is not None : arr.append(y)
        else : arr.append(0)
    else :
      for i in range(2) : arr.append(0)
  
  return(tuple(arr))
        
ScoreAndPosts = PostsByUser.fullOuterJoin(ScoreByUser).map(lambda line : (line[0],map_null(line[1])))
#Format - (UserId,(Total Words,No. of Posts,Total Score,No. of Comments))

# %% [markdown]
# For the next 2 steps : (Please look at code for format of data at each step)
# * Now we can join the RDD from last step -ScoreAndPosts- with -UserDisplayName- RDD to get the Display Names of the users.
# * By using 'sortBy' method and the position of 'Total Score' as key, data is sorted in descending order.
#
#
# Finally, we will now export the resulting dataset consisting all the necessary fields into a csv file.
#
# We can sure use the built-in function 'saveAsTextFile()' to export the RDD, but the problem with this, spark divides the data into parts and exports in multiple files. So to get a single file, we can use python File libraries. To do that, We will collect the data into memory and then iterate through each row to add it to the file after necessary conversions. So that, the file is ready to be read for any other purposes in multiple platforms.

# %%
FinalUserScore = UserDisplayName.join(ScoreAndPosts)
#Format - (UserID,(DisplayName,(Total Words,No. of Posts,Total Score,No. of Comments)))

FinalScoreSorted = FinalUserScore.sortBy(lambda line : line[1][1][2],False)

FinalScoreOut = FinalScoreSorted.map(lambda line : (line[0],line[1][0],line[1][1][3],line[1][1][2],line[1][1][1]))
print('UserID, DisplayName, No.of Comments, Total Score, No.of Posts\n')
pprint(FinalScoreOut.take(10))

### Code to output an RDD to a text-file ###
#Format - (UserID,DisplayName,No. of Comments,Total Score,No. of Posts)

Fileout = open("FinalScore.csv","w")
Fileout.write("Id,DisplayName,NoofComments,TotalScore,NoofPosts\n")
for line in FinalScoreOut.collect() :
    Fileout.write(','.join(str(var) for var in line))
    Fileout.write('\n')

print('\nThe data is successfully exported to the file :',Fileout.name)
Fileout.close()

### Built-in function ###
#FinalScoreOut.saveAsTextFile("FinalScore.csv")
# Out:
# UserID, DisplayName, No.of Comments, Total Score, No.of Posts
#
# [('381', 'Emre', 1246, 684, 440),
#  ('836', 'Neil Slater', 1199, 544, 1180),
#  ('471', 'Spacedman', 325, 177, 111),
#  ('28175', 'Vaalizaadeh', 839, 170, 1249),
#  ('21', 'Sean Owen', 345, 150, 1193),
#  ('8820', 'Martin Thoma', 277, 132, 648),
#  ('35644', 'Aditya', 627, 123, 221),
#  ('924', 'Anony-Mousse', 463, 117, 447),
#  ('23305', 'oW_', 255, 101, 421),
#  ('11097', 'Dawny33', 285, 95, 702)]
#
# The data is successfully exported to the file : FinalScore.csv
